# %%
import pandas as pd
import numpy as np
import pickle

# %%
impression_df = pd.read_csv('./impressions-train.csv')
final_rating_df = pd.read_csv('./ratings-final.csv')
final_test_df = pd.read_csv('./test.csv')

# %%
with open('./rec_on_impression_5_both', 'rb') as f:
    rec_on_impression = pickle.load(f)
with open('./rec_on_final_rating_5', 'rb') as f:
    rec_on_final_rating = pickle.load(f)

# %%
impression_cleaned_df = impression_df.drop_duplicates(subset=['reviewerid', 'movie-code'], keep=False)
final_rating_cleaned_df = final_rating_df.drop_duplicates(subset=['reviewerid', 'movie-code'], keep=False)

# %%
# for test
# impression_cleaned_df_test = final_test_df

# for validation
impression_cleaned_df_test = impression_cleaned_df.sample(frac=0.2, random_state=7, axis=0)
impression_cleaned_df = impression_cleaned_df[~impression_cleaned_df.index.isin(impression_cleaned_df_test.index)]

# %% [markdown]
# # Feature Engineering

# %%
impression_rating_mean = impression_cleaned_df.groupby(['reviewerid']).mean()
impression_rating_mean = impression_rating_mean.reset_index()
impression_rating_mean.rename(columns={'rating':'reviewer_impression_mean'},inplace=True)

# %%
impression_cleaned_df_feature = pd.merge(impression_cleaned_df, impression_rating_mean[['reviewerid', 'reviewer_impression_mean']], how='left', on=['reviewerid'])

# %%
movie_rating_mean = impression_cleaned_df.groupby(['movie-code']).mean()
movie_rating_mean = movie_rating_mean.reset_index()
movie_rating_mean.rename(columns={'rating':'movie_impression_mean'},inplace=True)

# %%
impression_cleaned_df_feature = pd.merge(impression_cleaned_df_feature, movie_rating_mean[['movie-code', 'movie_impression_mean']], how='left', on=['movie-code'])

# %%
impression_rating_max = impression_cleaned_df.groupby(['reviewerid']).max()
impression_rating_max = impression_rating_max.reset_index()
impression_rating_max.rename(columns={'rating':'reviewer_impression_max'},inplace=True)

# %%
impression_cleaned_df_feature = pd.merge(impression_cleaned_df_feature, impression_rating_max[['reviewerid', 'reviewer_impression_max']], how='left', on=['reviewerid'])

# %%
impression_rating_min = impression_cleaned_df.groupby(['reviewerid']).min()
impression_rating_min = impression_rating_min.reset_index()
impression_rating_min.rename(columns={'rating':'reviewer_impression_min'},inplace=True)

# %%
impression_cleaned_df_feature = pd.merge(impression_cleaned_df_feature, impression_rating_min[['reviewerid', 'reviewer_impression_min']], how='left', on=['reviewerid'])

# %%
user_rating_count = impression_cleaned_df.groupby(['reviewerid']).count()
user_rating_count = user_rating_count.reset_index()
user_rating_count.rename(columns={'rating':'reviewer_rating_count'},inplace=True)

# %%
impression_cleaned_df_feature = pd.merge(impression_cleaned_df_feature, user_rating_count[['reviewerid', 'reviewer_rating_count']], how='left', on=['reviewerid'])

# %%
movie_rating_count = impression_cleaned_df.groupby(['movie-code']).count()
movie_rating_count = movie_rating_count.reset_index()
movie_rating_count.rename(columns={'rating':'movie_rating_count'},inplace=True)

# %%
impression_cleaned_df_feature = pd.merge(impression_cleaned_df_feature, movie_rating_count[['movie-code', 'movie_rating_count']], how='left', on=['movie-code'])

# %%
impression_rating_std = impression_cleaned_df.groupby(['reviewerid']).std()
impression_rating_std = impression_rating_std.reset_index()
impression_rating_std.rename(columns={'rating':'reviewer_impression_std'},inplace=True)

# %%
impression_cleaned_df_feature = pd.merge(impression_cleaned_df_feature, impression_rating_std[['reviewerid', 'reviewer_impression_std']], how='left', on=['reviewerid'])

# %%
movie_rating_std = impression_cleaned_df.groupby(['movie-code']).std()
movie_rating_std = movie_rating_std.reset_index()
movie_rating_std.rename(columns={'rating':'movie_impression_std'},inplace=True)

# %%
impression_cleaned_df_feature = pd.merge(impression_cleaned_df_feature, movie_rating_std[['movie-code', 'movie_impression_std']], how='left', on=['movie-code'])

# %%
reviewer_each_rating_count = impression_cleaned_df.groupby(['reviewerid','rating']).count()
reviewer_each_rating_count = reviewer_each_rating_count.reset_index()
reviewer_each_rating_count.rename(columns={'movie-code':'reviewer_each_rating_count'},inplace=True)

# %%
impression_cleaned_df_feature = pd.merge(impression_cleaned_df_feature, 
                                         reviewer_each_rating_count[reviewer_each_rating_count['rating']==0][['reviewerid', 'reviewer_each_rating_count']], 
                                         how='left', on=['reviewerid'])
impression_cleaned_df_feature.rename(columns={'reviewer_each_rating_count':'reviewer_rating_count_0'},inplace=True)

impression_cleaned_df_feature = pd.merge(impression_cleaned_df_feature, 
                                         reviewer_each_rating_count[reviewer_each_rating_count['rating']==1][['reviewerid', 'reviewer_each_rating_count']], 
                                         how='left', on=['reviewerid'])
impression_cleaned_df_feature.rename(columns={'reviewer_each_rating_count':'reviewer_rating_count_1'},inplace=True)

impression_cleaned_df_feature = pd.merge(impression_cleaned_df_feature, 
                                         reviewer_each_rating_count[reviewer_each_rating_count['rating']==2][['reviewerid', 'reviewer_each_rating_count']], 
                                         how='left', on=['reviewerid'])
impression_cleaned_df_feature.rename(columns={'reviewer_each_rating_count':'reviewer_rating_count_2'},inplace=True)

# %%
impression_cleaned_df_feature[['reviewer_rating_count_0','reviewer_rating_count_1','reviewer_rating_count_2']] = impression_cleaned_df_feature[['reviewer_rating_count_0','reviewer_rating_count_1','reviewer_rating_count_2']].fillna(0)

# %%
impression_cleaned_df_feature['reviewer_rating_percent_0'] = impression_cleaned_df_feature.apply(lambda row: row['reviewer_rating_count_0']/row['reviewer_rating_count'], axis=1)
impression_cleaned_df_feature['reviewer_rating_percent_1'] = impression_cleaned_df_feature.apply(lambda row: row['reviewer_rating_count_1']/row['reviewer_rating_count'], axis=1)
impression_cleaned_df_feature['reviewer_rating_percent_2'] = impression_cleaned_df_feature.apply(lambda row: row['reviewer_rating_count_2']/row['reviewer_rating_count'], axis=1)

# %%
movie_each_rating_count = impression_cleaned_df.groupby(['movie-code','rating']).count()
movie_each_rating_count = movie_each_rating_count.reset_index()
movie_each_rating_count.rename(columns={'reviewerid':'movie_each_rating_count'},inplace=True)

# %%
impression_cleaned_df_feature = pd.merge(impression_cleaned_df_feature, 
                                         movie_each_rating_count[movie_each_rating_count['rating']==0][['movie-code', 'movie_each_rating_count']], 
                                         how='left', on=['movie-code'])
impression_cleaned_df_feature.rename(columns={'movie_each_rating_count':'movie_rating_count_0'},inplace=True)

impression_cleaned_df_feature = pd.merge(impression_cleaned_df_feature, 
                                         movie_each_rating_count[movie_each_rating_count['rating']==1][['movie-code', 'movie_each_rating_count']], 
                                         how='left', on=['movie-code'])
impression_cleaned_df_feature.rename(columns={'movie_each_rating_count':'movie_rating_count_1'},inplace=True)

impression_cleaned_df_feature = pd.merge(impression_cleaned_df_feature, 
                                         movie_each_rating_count[movie_each_rating_count['rating']==2][['movie-code', 'movie_each_rating_count']], 
                                         how='left', on=['movie-code'])
impression_cleaned_df_feature.rename(columns={'movie_each_rating_count':'movie_rating_count_2'},inplace=True)

# %%
impression_cleaned_df_feature[['movie_rating_count_0','movie_rating_count_1','movie_rating_count_2']] = impression_cleaned_df_feature[['movie_rating_count_0','movie_rating_count_1','movie_rating_count_2']].fillna(0)

# %%
impression_cleaned_df_feature['movie_rating_percent_0'] = impression_cleaned_df_feature.apply(lambda row: row['movie_rating_count_0']/row['movie_rating_count'], axis=1)
impression_cleaned_df_feature['movie_rating_percent_1'] = impression_cleaned_df_feature.apply(lambda row: row['movie_rating_count_1']/row['movie_rating_count'], axis=1)
impression_cleaned_df_feature['movie_rating_percent_2'] = impression_cleaned_df_feature.apply(lambda row: row['movie_rating_count_2']/row['movie_rating_count'], axis=1)

# %%
movie_final_rating_mean = final_rating_cleaned_df.groupby(['movie-code']).mean()
movie_final_rating_mean = movie_final_rating_mean.reset_index()
movie_final_rating_mean.rename(columns={'rating-final':'movie_final_mean'},inplace=True)

# %%
impression_cleaned_df_feature = pd.merge(impression_cleaned_df_feature, movie_final_rating_mean[['movie-code', 'movie_final_mean']], how='left', on=['movie-code'])

# %%
movie_final_rating_std = final_rating_cleaned_df.groupby(['movie-code']).std()
movie_final_rating_std = movie_final_rating_std.reset_index()
movie_final_rating_std.rename(columns={'rating-final':'movie_final_std'},inplace=True)

# %%
impression_cleaned_df_feature = pd.merge(impression_cleaned_df_feature, movie_final_rating_std[['movie-code', 'movie_final_std']], how='left', on=['movie-code'])

# %%
movie_final_rating_count = final_rating_cleaned_df.groupby(['movie-code']).count()
movie_final_rating_count = movie_final_rating_count.reset_index()
movie_final_rating_count.rename(columns={'rating-final':'movie_final_count'},inplace=True)

# %%
impression_cleaned_df_feature = pd.merge(impression_cleaned_df_feature, movie_final_rating_count[['movie-code', 'movie_final_count']], how='left', on=['movie-code'])

# %%
reviewer_final_rating_mean = final_rating_cleaned_df.groupby(['reviewerid']).mean()
reviewer_final_rating_mean = reviewer_final_rating_mean.reset_index()
reviewer_final_rating_mean.rename(columns={'rating-final':'reviewer_final_mean'},inplace=True)

# %%
impression_cleaned_df_feature = pd.merge(impression_cleaned_df_feature, reviewer_final_rating_mean[['reviewerid', 'reviewer_final_mean']], how='left', on=['reviewerid'])

# %%
reviewer_final_rating_std = final_rating_cleaned_df.groupby(['reviewerid']).std()
reviewer_final_rating_std = reviewer_final_rating_std.reset_index()
reviewer_final_rating_std.rename(columns={'rating-final':'reviewer_final_std'},inplace=True)

# %%
impression_cleaned_df_feature = pd.merge(impression_cleaned_df_feature, reviewer_final_rating_std[['reviewerid', 'reviewer_final_std']], how='left', on=['reviewerid'])

# %%
reviewer_final_rating_count = final_rating_cleaned_df.groupby(['reviewerid']).count()
reviewer_final_rating_count = reviewer_final_rating_count.reset_index()
reviewer_final_rating_count.rename(columns={'rating-final':'reviewer_final_count'},inplace=True)

# %%
impression_cleaned_df_feature = pd.merge(impression_cleaned_df_feature, reviewer_final_rating_count[['reviewerid', 'reviewer_final_count']], how='left', on=['reviewerid'])

# %%
reviewer_final_each_rating_count = final_rating_cleaned_df.groupby(['reviewerid','rating-final']).count()
reviewer_final_each_rating_count = reviewer_final_each_rating_count.reset_index()
reviewer_final_each_rating_count.rename(columns={'movie-code':'reviewer_each_rating_count'},inplace=True)

# %%
impression_cleaned_df_feature = pd.merge(impression_cleaned_df_feature, 
                                         reviewer_final_each_rating_count[reviewer_final_each_rating_count['rating-final']==0][['reviewerid', 'reviewer_each_rating_count']], 
                                         how='left', on=['reviewerid'])
impression_cleaned_df_feature.rename(columns={'reviewer_each_rating_count':'reviewer_final_rating_count_0'},inplace=True)

impression_cleaned_df_feature = pd.merge(impression_cleaned_df_feature, 
                                         reviewer_final_each_rating_count[reviewer_final_each_rating_count['rating-final']==1][['reviewerid', 'reviewer_each_rating_count']], 
                                         how='left', on=['reviewerid'])
impression_cleaned_df_feature.rename(columns={'reviewer_each_rating_count':'reviewer_final_rating_count_1'},inplace=True)

impression_cleaned_df_feature = pd.merge(impression_cleaned_df_feature, 
                                         reviewer_final_each_rating_count[reviewer_final_each_rating_count['rating-final']==2][['reviewerid', 'reviewer_each_rating_count']], 
                                         how='left', on=['reviewerid'])
impression_cleaned_df_feature.rename(columns={'reviewer_each_rating_count':'reviewer_final_rating_count_2'},inplace=True)

# %%
impression_cleaned_df_feature[['reviewer_final_rating_count_0','reviewer_final_rating_count_1','reviewer_final_rating_count_2']] = impression_cleaned_df_feature[['reviewer_final_rating_count_0','reviewer_final_rating_count_1','reviewer_final_rating_count_2']].fillna(0)

# %%
impression_cleaned_df_feature['reviewer_final_rating_percent_0'] = impression_cleaned_df_feature.apply(lambda row: row['reviewer_final_rating_count_0']/row['reviewer_final_count'], axis=1)
impression_cleaned_df_feature['reviewer_final_rating_percent_1'] = impression_cleaned_df_feature.apply(lambda row: row['reviewer_final_rating_count_1']/row['reviewer_final_count'], axis=1)
impression_cleaned_df_feature['reviewer_final_rating_percent_2'] = impression_cleaned_df_feature.apply(lambda row: row['reviewer_final_rating_count_2']/row['reviewer_final_count'], axis=1)

# %%
movie_final_each_rating_count = final_rating_cleaned_df.groupby(['movie-code','rating-final']).count()
movie_final_each_rating_count = movie_final_each_rating_count.reset_index()
movie_final_each_rating_count.rename(columns={'reviewerid':'movie_each_rating_count'},inplace=True)

# %%
impression_cleaned_df_feature = pd.merge(impression_cleaned_df_feature, 
                                         movie_final_each_rating_count[movie_final_each_rating_count['rating-final']==0][['movie-code', 'movie_each_rating_count']], 
                                         how='left', on=['movie-code'])
impression_cleaned_df_feature.rename(columns={'movie_each_rating_count':'movie_final_rating_count_0'},inplace=True)

impression_cleaned_df_feature = pd.merge(impression_cleaned_df_feature, 
                                         movie_final_each_rating_count[movie_final_each_rating_count['rating-final']==1][['movie-code', 'movie_each_rating_count']], 
                                         how='left', on=['movie-code'])
impression_cleaned_df_feature.rename(columns={'movie_each_rating_count':'movie_final_rating_count_1'},inplace=True)

impression_cleaned_df_feature = pd.merge(impression_cleaned_df_feature, 
                                         movie_final_each_rating_count[movie_final_each_rating_count['rating-final']==2][['movie-code', 'movie_each_rating_count']], 
                                         how='left', on=['movie-code'])
impression_cleaned_df_feature.rename(columns={'movie_each_rating_count':'movie_final_rating_count_2'},inplace=True)

# %%
impression_cleaned_df_feature[['movie_final_rating_count_0','movie_final_rating_count_1','movie_final_rating_count_2']] = impression_cleaned_df_feature[['movie_final_rating_count_0','movie_final_rating_count_1','movie_final_rating_count_2']].fillna(0)

# %%
impression_cleaned_df_feature['movie_final_rating_percent_0'] = impression_cleaned_df_feature.apply(lambda row: row['movie_final_rating_count_0']/row['movie_final_count'], axis=1)
impression_cleaned_df_feature['movie_final_rating_percent_1'] = impression_cleaned_df_feature.apply(lambda row: row['movie_final_rating_count_1']/row['movie_final_count'], axis=1)
impression_cleaned_df_feature['movie_final_rating_percent_2'] = impression_cleaned_df_feature.apply(lambda row: row['movie_final_rating_count_2']/row['movie_final_count'], axis=1)

# %%
impression_cleaned_df_feature['movie_mean_difference'] = impression_cleaned_df_feature.apply(lambda row: row['movie_final_mean'] - row['movie_impression_mean'], axis=1)

# %%
impression_cleaned_df_feature['reviewerid'].map(rec_on_impression)
# Out:
# 0           [(21, 2), (131, 2), (77, 2), (88, 2), (90, 2)]
# 1        [(147, 2), (129, 2), (154, 2), (104, 2), (114,...
# 2          [(131, 2), (77, 2), (88, 2), (90, 2), (122, 2)]
# 3         [(179, 2), (165, 2), (21, 2), (131, 2), (77, 2)]
# 4         [(179, 2), (165, 2), (21, 2), (131, 2), (77, 2)]
#                                ...
# 21700      [(124, 2), (60, 2), (44, 2), (35, 2), (168, 2)]
# 21701     [(179, 2), (165, 2), (131, 2), (77, 2), (88, 2)]
# 21702      [(52, 2), (133, 2), (91, 2), (55, 2), (149, 2)]
# 21703     [(179, 2), (165, 2), (131, 2), (88, 2), (90, 2)]
# 21704    [(165, 2), (21, 2), (131, 2), (122, 2), (102, 2)]
# Name: reviewerid, Length: 21705, dtype: object

# %%
rec_1 = impression_cleaned_df_feature['reviewerid'].map(rec_on_impression)
rec_2 = impression_cleaned_df_feature['reviewerid'].map(rec_on_final_rating)

rec_1_0 = [r[0][0] for r in rec_1]
rec_1_1 = [r[1][0] for r in rec_1]
rec_1_2 = [r[2][0] for r in rec_1]
rec_1_3 = [r[3][0] for r in rec_1]
rec_1_4 = [r[4][0] for r in rec_1]

rec_1_0_s = [r[0][1] for r in rec_1]
rec_1_1_s = [r[1][1] for r in rec_1]
rec_1_2_s = [r[2][1] for r in rec_1]
rec_1_3_s = [r[3][1] for r in rec_1]
rec_1_4_s = [r[4][1] for r in rec_1]

rec_2_0 = [r[0] for r in rec_2]
rec_2_1 = [r[1] for r in rec_2]
rec_2_2 = [r[2] for r in rec_2]
rec_2_3 = [r[3] for r in rec_2]
rec_2_4 = [r[4] for r in rec_2]

# %%
impression_cleaned_df_feature['impression_rec_0'] = rec_1_0
impression_cleaned_df_feature['impression_rec_0_score'] = rec_1_0_s

impression_cleaned_df_feature['impression_rec_1'] = rec_1_1
impression_cleaned_df_feature['impression_rec_1_score'] = rec_1_1_s

impression_cleaned_df_feature['impression_rec_2'] = rec_1_2
impression_cleaned_df_feature['impression_rec_2_score'] = rec_1_2_s

impression_cleaned_df_feature['impression_rec_3'] = rec_1_3
impression_cleaned_df_feature['impression_rec_3_score'] = rec_1_3_s

impression_cleaned_df_feature['impression_rec_4'] = rec_1_4
impression_cleaned_df_feature['impression_rec_4_score'] = rec_1_4_s

impression_cleaned_df_feature['final_rating_rec_0'] = rec_2_0
impression_cleaned_df_feature['final_rating_rec_1'] = rec_2_1
impression_cleaned_df_feature['final_rating_rec_2'] = rec_2_2
impression_cleaned_df_feature['final_rating_rec_3'] = rec_2_3
impression_cleaned_df_feature['final_rating_rec_4'] = rec_2_4

# %%
impression_cleaned_df_feature
# Out:
#        reviewerid  movie-code  rating  reviewer_impression_mean  \
# 0             116         150       0                  0.070175
# 1             328          56       2                  0.447368
# 2             181         181       0                  0.440000
# 3             131           6       0                  0.666667
# 4             236          24       2                  0.547619
# ...           ...         ...     ...                       ...
# 21700         405          14       1                  0.500000
# 21701          59          51       0                  0.593750
# 21702         421          58       2                  1.194444
# 21703         263          57       0                  0.361702
# 21704          70          52       0                  0.718750
#
#        movie_impression_mean  reviewer_impression_max  \
# 0                   0.298780                        1
# 1                   0.468750                        2
# 2                   0.324468                        2
# 3                   0.546218                        2
# 4                   1.055556                        2
# ...                      ...                      ...
# 21700               0.441176                        2
# 21701               0.559441                        2
# 21702               0.503650                        2
# 21703               0.397959                        2
# 21704               0.532710                        2
#
#        reviewer_impression_min  reviewer_rating_count  movie_rating_count  \
# 0                            0                     57                 164
# 1                            0                     38                  96
# 2                            0                     50                 188
# 3                            0                     21                 238
# 4                            0                     42                 162
# ...                        ...                    ...                 ...
# 21700                        0                     18                 136
# 21701                        0                     32                 143
# 21702                        0                     36                 137
# 21703                        0                     47                  98
# 21704                        0                     32                 107
#
#        reviewer_impression_std  ...  impression_rec_2_score  impression_rec_3  \
# 0                     0.257713  ...                       2                88
# 1                     0.601681  ...                       2               104
# 2                     0.611455  ...                       2                90
# 3                     0.658281  ...                       2               131
# 4                     0.771517  ...                       2               131
# ...                        ...  ...                     ...               ...
# 21700                 0.618347  ...                       2                35
# 21701                 0.712079  ...                       2                77
# 21702                 0.668450  ...                       2                55
# 21703                 0.528556  ...                       2                88
# 21704                 0.812578  ...                       2               122
#
#        impression_rec_3_score  impression_rec_4  impression_rec_4_score  \
# 0                           2                90                       2
# 1                           2               114                       2
# 2                           2               122                       2
# 3                           2                77                       2
# 4                           2                77                       2
# ...                       ...               ...                     ...
# 21700                       2               168                       2
# 21701                       2                88                       2
# 21702                       2               149                       2
# 21703                       2                90                       2
# 21704                       2               102                       2
#
#        final_rating_rec_0  final_rating_rec_1  final_rating_rec_2  \
# 0                     191                  53                  64
# 1                     167                 181                 144
# 2                      79                 182                  39
# 3                      32                  13                  68
# 4                     133                  32                  30
# ...                   ...                 ...                 ...
# 21700                  99                  73                  39
# 21701                  51                 177                 183
# 21702                 132                 155                  73
# 21703                  72                 112                  97
# 21704                 133                  32                  13
#
#        final_rating_rec_3  final_rating_rec_4
# 0                     187                  57
# 1                     152                 194
# 2                      32                 108
# 3                      20                  27
# 4                      13                  74
# ...                   ...                 ...
# 21700                  32                 108
# 21701                   1                 102
# 21702                  32                 108
# 21703                  31                  64
# 21704                  21                 138
#
# [21705 rows x 57 columns]

# %%
columns = impression_cleaned_df_feature.columns

# %%
columns
# Out:
# Index(['reviewerid', 'movie-code', 'rating', 'reviewer_impression_mean',
#        'movie_impression_mean', 'reviewer_impression_max',
#        'reviewer_impression_min', 'reviewer_rating_count',
#        'movie_rating_count', 'reviewer_impression_std', 'movie_impression_std',
#        'reviewer_rating_count_0', 'reviewer_rating_count_1',
#        'reviewer_rating_count_2', 'reviewer_rating_percent_0',
#        'reviewer_rating_percent_1', 'reviewer_rating_percent_2',
#        'movie_rating_count_0', 'movie_rating_count_1', 'movie_rating_count_2',
#        'movie_rating_percent_0', 'movie_rating_percent_1',
#        'movie_rating_percent_2', 'movie_final_mean', 'movie_final_std',
#        'movie_final_count', 'reviewer_final_mean', 'reviewer_final_std',
#        'reviewer_final_count', 'reviewer_final_rating_count_0',
#        'reviewer_final_rating_count_1', 'reviewer_final_rating_count_2',
#        'reviewer_final_rating_percent_0', 'reviewer_final_rating_percent_1',
#        'reviewer_final_rating_percent_2', 'movie_final_rating_count_0',
#        'movie_final_rating_count_1', 'movie_final_rating_count_2',
#        'movie_final_rating_percent_0', 'movie_final_rating_percent_1',
#        'movie_final_rating_percent_2', 'movie_mean_difference',
#        'impression_rec_0', 'impression_rec_0_score', 'impression_rec_1',
#        'impression_rec_1_score', 'impression_rec_2', 'impression_rec_2_score',
#        'impression_rec_3', 'impression_rec_3_score', 'impression_rec_4',
#        'impression_rec_4_score', 'final_rating_rec_0', 'final_rating_rec_1',
#        'final_rating_rec_2', 'final_rating_rec_3', 'final_rating_rec_4'],
#       dtype='object')

# %%
reviewer_based_feature = ['reviewerid',
 'reviewer_impression_mean',
 'reviewer_impression_max',
 'reviewer_impression_min',
 'reviewer_rating_count',
 'reviewer_impression_std',
 'reviewer_rating_count_0',
 'reviewer_rating_count_1',
 'reviewer_rating_count_2',
 'reviewer_rating_percent_0',
 'reviewer_rating_percent_1',
 'reviewer_rating_percent_2',
 'reviewer_final_mean',
 'reviewer_final_std',
 'reviewer_final_count',
 'reviewer_final_rating_count_0',
 'reviewer_final_rating_count_1',
 'reviewer_final_rating_count_2',
 'reviewer_final_rating_percent_0',
 'reviewer_final_rating_percent_1',
 'reviewer_final_rating_percent_2',
 'impression_rec_0',
 'impression_rec_0_score',
 'impression_rec_1',
 'impression_rec_1_score',
 'impression_rec_2',
 'impression_rec_2_score',
 'impression_rec_3',
 'impression_rec_3_score',
 'impression_rec_4',
 'impression_rec_4_score',
 'final_rating_rec_0',
 'final_rating_rec_1',
 'final_rating_rec_2',
 'final_rating_rec_3',
 'final_rating_rec_4']

movie_based_feature = ['movie-code',
 'movie_impression_mean',
 'movie_rating_count',
 'movie_impression_std',
 'movie_rating_count_0',
 'movie_rating_count_1',
 'movie_rating_count_2',
 'movie_rating_percent_0',
 'movie_rating_percent_1',
 'movie_rating_percent_2',
 'movie_final_mean',
 'movie_final_std',
 'movie_final_count',
 'movie_final_rating_count_0',
 'movie_final_rating_count_1',
 'movie_final_rating_count_2',
 'movie_final_rating_percent_0',
 'movie_final_rating_percent_1',
 'movie_final_rating_percent_2',
 'movie_mean_difference']

feature_columns = ['reviewer_impression_mean',
 'movie_impression_mean',
 'reviewer_impression_max',
 'reviewer_impression_min',
 'reviewer_rating_count',
 'movie_rating_count',
 'reviewer_impression_std',
 'movie_impression_std',
 'reviewer_rating_count_0',
 'reviewer_rating_count_1',
 'reviewer_rating_count_2',
 'reviewer_rating_percent_0',
 'reviewer_rating_percent_1',
 'reviewer_rating_percent_2',
 'movie_rating_count_0',
 'movie_rating_count_1',
 'movie_rating_count_2',
 'movie_rating_percent_0',
 'movie_rating_percent_1',
 'movie_rating_percent_2',
 'movie_final_mean',
 'movie_final_std',
 'movie_final_count',
 'reviewer_final_mean',
 'reviewer_final_std',
 'reviewer_final_count',
 'reviewer_final_rating_count_0',
 'reviewer_final_rating_count_1',
 'reviewer_final_rating_count_2',
 'reviewer_final_rating_percent_0',
 'reviewer_final_rating_percent_1',
 'reviewer_final_rating_percent_2',
 'movie_final_rating_count_0',
 'movie_final_rating_count_1',
 'movie_final_rating_count_2',
 'movie_final_rating_percent_0',
 'movie_final_rating_percent_1',
 'movie_final_rating_percent_2',
 'movie_mean_difference',
 'impression_rec_0',
 'impression_rec_0_score',
 'impression_rec_1',
 'impression_rec_1_score',
 'impression_rec_2',
 'impression_rec_2_score',
 'impression_rec_3',
 'impression_rec_3_score',
 'impression_rec_4',
 'impression_rec_4_score',
 'final_rating_rec_0',
 'final_rating_rec_1',
 'final_rating_rec_2',
 'final_rating_rec_3',
 'final_rating_rec_4']

std_columns = ['reviewer_impression_max',
 'reviewer_impression_min',
 'reviewer_rating_count',
 'movie_rating_count',
 'movie_final_count',
 'reviewer_final_count']

# %%
print(len(feature_columns))
print(len(movie_based_feature)+len(reviewer_based_feature))
# Out:
# 54
# 56

# %% [markdown]
# # training data prepare

# %%
impression_cleaned_df_test_feature = pd.merge(impression_cleaned_df_test, impression_cleaned_df_feature[reviewer_based_feature].drop_duplicates(subset=['reviewerid']), how='left', on=['reviewerid'])
impression_cleaned_df_test_feature = pd.merge(impression_cleaned_df_test_feature, impression_cleaned_df_feature[movie_based_feature].drop_duplicates(subset=['movie-code']), how='left', on=['movie-code'])

# %%
impression_cleaned_df_test_feature
# Out:
#       reviewerid  movie-code  rating  reviewer_impression_mean  \
# 0             68         111       0                  0.142857
# 1            524          28       0                  0.553191
# 2             54          37       1                  0.545455
# 3             60          59       0                  0.191176
# 4            409         119       1                  0.678571
# ...          ...         ...     ...                       ...
# 5421         182         174       0                  0.468750
# 5422         237         143       0                  0.269231
# 5423         368         131       0                  0.244898
# 5424          89           8       1                  0.727273
# 5425         558         180       1                  0.979592
#
#       reviewer_impression_max  reviewer_impression_min  reviewer_rating_count  \
# 0                           2                        0                     35
# 1                           2                        0                     47
# 2                           2                        0                     22
# 3                           2                        0                     68
# 4                           2                        0                     56
# ...                       ...                      ...                    ...
# 5421                        2                        0                     32
# 5422                        1                        0                     26
# 5423                        2                        0                     49
# 5424                        2                        0                     44
# 5425                        2                        0                     49
#
#       reviewer_impression_std  reviewer_rating_count_0  \
# 0                    0.493657                     32.0
# 1                    0.746252                     28.0
# 2                    0.800433                     14.0
# 3                    0.432188                     56.0
# 4                    0.690379                     25.0
# ...                       ...                      ...
# 5421                 0.717719                     21.0
# 5422                 0.452344                     19.0
# 5423                 0.630166                     42.0
# 5424                 0.788394                     21.0
# 5425                 0.558637                      8.0
#
#       reviewer_rating_count_1  ...  movie_final_mean  movie_final_std  \
# 0                         1.0  ...          1.381818         0.693812
# 1                        12.0  ...          1.519663         0.611768
# 2                         4.0  ...          1.264368         0.738631
# 3                        11.0  ...          1.667464         0.585143
# 4                        24.0  ...          1.438596         0.665657
# ...                       ...  ...               ...              ...
# 5421                      7.0  ...          1.409231         0.658684
# 5422                      7.0  ...          1.394366         0.714170
# 5423                      2.0  ...          1.116279         0.697250
# 5424                     14.0  ...          1.269231         0.789824
# 5425                     34.0  ...          1.614679         0.635483
#
#       movie_final_count  movie_final_rating_count_0  \
# 0                   165                          20
# 1                   356                          22
# 2                    87                          15
# 3                   418                          25
# 4                   114                          11
# ...                 ...                         ...
# 5421                325                          31
# 5422                142                          19
# 5423                 43                           8
# 5424                156                          33
# 5425                218                          18
#
#       movie_final_rating_count_1  movie_final_rating_count_2  \
# 0                             62                          83
# 1                            127                         207
# 2                             34                          38
# 3                             89                         304
# 4                             42                          61
# ...                          ...                         ...
# 5421                         130                         164
# 5422                          48                          75
# 5423                          22                          13
# 5424                          48                          75
# 5425                          48                         152
#
#       movie_final_rating_percent_0  movie_final_rating_percent_1  \
# 0                         0.121212                      0.375758
# 1                         0.061798                      0.356742
# 2                         0.172414                      0.390805
# 3                         0.059809                      0.212919
# 4                         0.096491                      0.368421
# ...                            ...                           ...
# 5421                      0.095385                      0.400000
# 5422                      0.133803                      0.338028
# 5423                      0.186047                      0.511628
# 5424                      0.211538                      0.307692
# 5425                      0.082569                      0.220183
#
#       movie_final_rating_percent_2  movie_mean_difference
# 0                         0.503030               0.923255
# 1                         0.581461               1.075218
# 2                         0.436782               0.701261
# 3                         0.727273               1.152313
# 4                         0.535088               0.806118
# ...                            ...                    ...
# 5421                      0.504615               0.834763
# 5422                      0.528169               0.727700
# 5423                      0.302326               0.646130
# 5424                      0.480769               0.706206
# 5425                      0.697248               1.206516
#
# [5426 rows x 57 columns]

# %%
train_set = np.zeros((21705, 2+len(feature_columns)))
valid_set = np.zeros((5426, 2+len(feature_columns)))

# %%
for index, row in impression_cleaned_df_feature.iterrows():
    train_set[index, 0] = row['reviewerid']
    train_set[index, 1] = row['movie-code']
    # train_set[index, 2:2+23] = movie_genre_map[row['movie-code']]
    # train_set[index, 573+201:573+201+768] = movie_bert_map[row['movie-code']]
    for col_idx, col_name in enumerate(feature_columns):
        train_set[index, 2+col_idx] = row[col_name]
for index, row in impression_cleaned_df_test_feature.iterrows():
    valid_set[index, 0] = row['reviewerid']
    valid_set[index, 1] = row['movie-code']
    # valid_set[index, 2:2+23] = movie_genre_map[row['movie-code']]
    # valid_set[index, 573+201:573+201+768] = movie_bert_map[row['movie-code']]
    
    for col_idx, col_name in enumerate(feature_columns):
        valid_set[index, 2+col_idx] = row[col_name]

# %%
train_y_label = impression_cleaned_df_feature['rating'].values

# %%
valid_y_label = impression_cleaned_df_test_feature['rating'].values

# %% [markdown]
# # XGBOOST

# %%
import xgboost as xgb
xg_train = xgb.DMatrix(train_set, label=train_y_label)
xg_valid = xgb.DMatrix(valid_set, label=valid_y_label)

# %%
# for final training
# xg_test_final = xgb.DMatrix(valid_set)

# %%
def point_cal(preds, dtrain):
    points = 0
    
    test_label = dtrain.get_label().tolist()
    pred = preds.tolist()
    
    for i in range(len(test_label)):
        if test_label[i] == pred[i]:
            points += 2
        else:
            if (test_label[i] == 1.0 and pred[i] == 2.0) or (test_label[i] == 2.0 and pred[i] == 1.0):
                points += 1
    return 'POINTS',points

# %%
params = {'booster':'gbtree',
         'objective':'multi:softmax',
         'gamma':0.1,
         'min_child_weight':1,
         'max_depth':6,
         'lambda':1,
         'subsample':0.5,
         'colsample_bytree':0.5,
         'colsample_bylevel':0.5,
         'eta':0.01,
         'tree_method':'exact',
         'num_class': 3,
         'gpu_id': 0,
         'tree_method': 'gpu_hist'}

watchlist = [ (xg_train,'train'), (xg_valid, 'test') ]
# watchlist = [ (xg_train,'train')]
num_round = 1400
bst = xgb.train(params, xg_train, num_round, watchlist, feval = point_cal)
# Out:
# [0]	train-merror:0.36945	test-merror:0.40435	train-POINTS:28864.00000	test-POINTS:6942.00000
# [1]	train-merror:0.36554	test-merror:0.39845	train-POINTS:29016.00000	test-POINTS:6982.00000
# [2]	train-merror:0.36222	test-merror:0.39919	train-POINTS:29194.00000	test-POINTS:6978.00000
# [3]	train-merror:0.36065	test-merror:0.39569	train-POINTS:29234.00000	test-POINTS:7002.00000
# [4]	train-merror:0.36070	test-merror:0.39643	train-POINTS:29195.00000	test-POINTS:6979.00000
# [5]	train-merror:0.36029	test-merror:0.39514	train-POINTS:29202.00000	test-POINTS:6987.00000
# [6]	train-merror:0.35950	test-merror:0.39569	train-POINTS:29230.00000	test-POINTS:6990.00000
# [7]	train-merror:0.35853	test-merror:0.39348	train-POINTS:29302.00000	test-POINTS:7006.00000
# [8]	train-merror:0.35840	test-merror:0.39274	train-POINTS:29308.00000	test-POINTS:7012.00000
# [9]	train-merror:0.35775	test-merror:0.39200	train-POINTS:29327.00000	test-POINTS:7021.00000
# [10]	train-merror:0.35853	test-merror:0.39237	train-POINTS:29286.00000	test-POINTS:7017.00000
# [11]	train-merror:0.35826	test-merror:0.39329	train-POINTS:29301.00000	test-POINTS:7012.00000
# [12]	train-merror:0.35840	test-merror:0.39292	train-POINTS:29309.00000	test-POINTS:7022.00000
# [13]	train-merror:0.35844	test-merror:0.39311	train-POINTS:29318.00000	test-POINTS:7025.00000
# [14]	train-merror:0.35886	test-merror:0.39182	train-POINTS:29293.00000	test-POINTS:7030.00000
# [15]	train-merror:0.35867	test-merror:0.39274	train-POINTS:29298.00000	test-POINTS:7023.00000
# [16]	train-merror:0.35812	test-merror:0.39440	train-POINTS:29317.00000	test-POINTS:7008.00000
# [17]	train-merror:0.35747	test-merror:0.39255	train-POINTS:29347.00000	test-POINTS:7029.00000
# [18]	train-merror:0.35798	test-merror:0.39421	train-POINTS:29318.00000	test-POINTS:7011.00000
# [19]	train-merror:0.35642	test-merror:0.39274	train-POINTS:29381.00000	test-POINTS:7025.00000
# [20]	train-merror:0.35697	test-merror:0.39311	train-POINTS:29356.00000	test-POINTS:7019.00000
# [21]	train-merror:0.35743	test-merror:0.39255	train-POINTS:29344.00000	test-POINTS:7032.00000
# [22]	train-merror:0.35724	test-merror:0.39348	train-POINTS:29357.00000	test-POINTS:7023.00000
# [23]	train-merror:0.35766	test-merror:0.39366	train-POINTS:29335.00000	test-POINTS:7024.00000
# [24]	train-merror:0.35724	test-merror:0.39274	train-POINTS:29349.00000	test-POINTS:7034.00000
# [25]	train-merror:0.35720	test-merror:0.39366	train-POINTS:29360.00000	test-POINTS:7024.00000
# [26]	train-merror:0.35655	test-merror:0.39366	train-POINTS:29371.00000	test-POINTS:7025.00000
# [27]	train-merror:0.35618	test-merror:0.39329	train-POINTS:29394.00000	test-POINTS:7026.00000
# [28]	train-merror:0.35628	test-merror:0.39274	train-POINTS:29397.00000	test-POINTS:7029.00000
# [29]	train-merror:0.35628	test-merror:0.39329	train-POINTS:29389.00000	test-POINTS:7023.00000
# [30]	train-merror:0.35600	test-merror:0.39182	train-POINTS:29400.00000	test-POINTS:7034.00000
# [31]	train-merror:0.35559	test-merror:0.39200	train-POINTS:29421.00000	test-POINTS:7031.00000
# [32]	train-merror:0.35540	test-merror:0.39255	train-POINTS:29428.00000	test-POINTS:7026.00000
# [33]	train-merror:0.35513	test-merror:0.39329	train-POINTS:29435.00000	test-POINTS:7022.00000
# [34]	train-merror:0.35559	test-merror:0.39421	train-POINTS:29413.00000	test-POINTS:7016.00000
# [35]	train-merror:0.35605	test-merror:0.39274	train-POINTS:29398.00000	test-POINTS:7025.00000
# [36]	train-merror:0.35568	test-merror:0.39219	train-POINTS:29406.00000	test-POINTS:7035.00000
# [37]	train-merror:0.35522	test-merror:0.39200	train-POINTS:29426.00000	test-POINTS:7036.00000
# [38]	train-merror:0.35490	test-merror:0.39163	train-POINTS:29442.00000	test-POINTS:7038.00000
# [39]	train-merror:0.35559	test-merror:0.39237	train-POINTS:29412.00000	test-POINTS:7033.00000
# [40]	train-merror:0.35536	test-merror:0.39311	train-POINTS:29419.00000	test-POINTS:7025.00000
# [41]	train-merror:0.35490	test-merror:0.39145	train-POINTS:29426.00000	test-POINTS:7038.00000
# [42]	train-merror:0.35522	test-merror:0.39200	train-POINTS:29414.00000	test-POINTS:7033.00000
# [43]	train-merror:0.35540	test-merror:0.39200	train-POINTS:29410.00000	test-POINTS:7035.00000
# [44]	train-merror:0.35485	test-merror:0.39182	train-POINTS:29430.00000	test-POINTS:7036.00000
# [45]	train-merror:0.35531	test-merror:0.39219	train-POINTS:29411.00000	test-POINTS:7036.00000
# [46]	train-merror:0.35531	test-merror:0.39219	train-POINTS:29414.00000	test-POINTS:7036.00000
# [47]	train-merror:0.35503	test-merror:0.39163	train-POINTS:29417.00000	test-POINTS:7038.00000
# [48]	train-merror:0.35517	test-merror:0.39292	train-POINTS:29414.00000	test-POINTS:7029.00000
# [49]	train-merror:0.35457	test-merror:0.39237	train-POINTS:29437.00000	test-POINTS:7032.00000
# [50]	train-merror:0.35457	test-merror:0.39255	train-POINTS:29442.00000	test-POINTS:7032.00000
# [51]	train-merror:0.35503	test-merror:0.39126	train-POINTS:29418.00000	test-POINTS:7046.00000
# [52]	train-merror:0.35457	test-merror:0.39219	train-POINTS:29440.00000	test-POINTS:7038.00000
# [53]	train-merror:0.35467	test-merror:0.39145	train-POINTS:29436.00000	test-POINTS:7043.00000
# [54]	train-merror:0.35420	test-merror:0.39182	train-POINTS:29453.00000	test-POINTS:7040.00000
# [55]	train-merror:0.35402	test-merror:0.39182	train-POINTS:29468.00000	test-POINTS:7038.00000
# [56]	train-merror:0.35379	test-merror:0.39145	train-POINTS:29478.00000	test-POINTS:7044.00000
# [57]	train-merror:0.35379	test-merror:0.39219	train-POINTS:29478.00000	test-POINTS:7037.00000
# [58]	train-merror:0.35416	test-merror:0.39163	train-POINTS:29464.00000	test-POINTS:7044.00000
# [59]	train-merror:0.35384	test-merror:0.39108	train-POINTS:29475.00000	test-POINTS:7047.00000
# [60]	train-merror:0.35388	test-merror:0.39126	train-POINTS:29469.00000	test-POINTS:7045.00000
# [61]	train-merror:0.35370	test-merror:0.39145	train-POINTS:29480.00000	test-POINTS:7047.00000
# [62]	train-merror:0.35379	test-merror:0.39200	train-POINTS:29481.00000	test-POINTS:7040.00000
# [63]	train-merror:0.35342	test-merror:0.39237	train-POINTS:29492.00000	test-POINTS:7037.00000
# [64]	train-merror:0.35342	test-merror:0.39237	train-POINTS:29492.00000	test-POINTS:7038.00000
# [65]	train-merror:0.35393	test-merror:0.39311	train-POINTS:29475.00000	test-POINTS:7033.00000
# [66]	train-merror:0.35379	test-merror:0.39274	train-POINTS:29486.00000	test-POINTS:7036.00000
# [67]	train-merror:0.35356	test-merror:0.39292	train-POINTS:29490.00000	test-POINTS:7035.00000
# [68]	train-merror:0.35287	test-merror:0.39255	train-POINTS:29516.00000	test-POINTS:7037.00000
# [69]	train-merror:0.35328	test-merror:0.39329	train-POINTS:29497.00000	test-POINTS:7032.00000
# [70]	train-merror:0.35296	test-merror:0.39237	train-POINTS:29511.00000	test-POINTS:7038.00000
# [71]	train-merror:0.35268	test-merror:0.39219	train-POINTS:29522.00000	test-POINTS:7039.00000
# [72]	train-merror:0.35301	test-merror:0.39219	train-POINTS:29511.00000	test-POINTS:7038.00000
# [73]	train-merror:0.35301	test-merror:0.39237	train-POINTS:29510.00000	test-POINTS:7037.00000
# [74]	train-merror:0.35305	test-merror:0.39200	train-POINTS:29510.00000	test-POINTS:7043.00000
# [75]	train-merror:0.35328	test-merror:0.39292	train-POINTS:29501.00000	test-POINTS:7034.00000
# [76]	train-merror:0.35305	test-merror:0.39274	train-POINTS:29515.00000	test-POINTS:7035.00000
# [77]	train-merror:0.35310	test-merror:0.39292	train-POINTS:29516.00000	test-POINTS:7033.00000
# [78]	train-merror:0.35282	test-merror:0.39292	train-POINTS:29523.00000	test-POINTS:7036.00000
# [79]	train-merror:0.35264	test-merror:0.39200	train-POINTS:29533.00000	test-POINTS:7043.00000
# [80]	train-merror:0.35273	test-merror:0.39219	train-POINTS:29528.00000	test-POINTS:7040.00000
# [81]	train-merror:0.35273	test-merror:0.39311	train-POINTS:29524.00000	test-POINTS:7030.00000
# [82]	train-merror:0.35268	test-merror:0.39274	train-POINTS:29531.00000	test-POINTS:7028.00000
# [83]	train-merror:0.35259	test-merror:0.39292	train-POINTS:29534.00000	test-POINTS:7027.00000
# [84]	train-merror:0.35250	test-merror:0.39311	train-POINTS:29537.00000	test-POINTS:7029.00000
# [85]	train-merror:0.35245	test-merror:0.39348	train-POINTS:29538.00000	test-POINTS:7025.00000
# [86]	train-merror:0.35241	test-merror:0.39348	train-POINTS:29544.00000	test-POINTS:7026.00000
# [87]	train-merror:0.35264	test-merror:0.39477	train-POINTS:29535.00000	test-POINTS:7016.00000
# [88]	train-merror:0.35264	test-merror:0.39366	train-POINTS:29536.00000	test-POINTS:7025.00000
# [89]	train-merror:0.35254	test-merror:0.39403	train-POINTS:29540.00000	test-POINTS:7022.00000
# [90]	train-merror:0.35241	test-merror:0.39477	train-POINTS:29543.00000	test-POINTS:7016.00000
# [91]	train-merror:0.35241	test-merror:0.39366	train-POINTS:29545.00000	test-POINTS:7025.00000
# [92]	train-merror:0.35222	test-merror:0.39384	train-POINTS:29550.00000	test-POINTS:7022.00000
# [93]	train-merror:0.35231	test-merror:0.39384	train-POINTS:29551.00000	test-POINTS:7024.00000
# [94]	train-merror:0.35213	test-merror:0.39421	train-POINTS:29556.00000	test-POINTS:7020.00000
# [95]	train-merror:0.35222	test-merror:0.39403	train-POINTS:29551.00000	test-POINTS:7024.00000
# [96]	train-merror:0.35222	test-merror:0.39403	train-POINTS:29557.00000	test-POINTS:7021.00000
# [97]	train-merror:0.35176	test-merror:0.39366	train-POINTS:29573.00000	test-POINTS:7028.00000
# [98]	train-merror:0.35181	test-merror:0.39403	train-POINTS:29570.00000	test-POINTS:7022.00000
# [99]	train-merror:0.35162	test-merror:0.39329	train-POINTS:29577.00000	test-POINTS:7029.00000
# [100]	train-merror:0.35158	test-merror:0.39348	train-POINTS:29580.00000	test-POINTS:7028.00000
# [101]	train-merror:0.35139	test-merror:0.39458	train-POINTS:29586.00000	test-POINTS:7019.00000
# [102]	train-merror:0.35162	test-merror:0.39403	train-POINTS:29576.00000	test-POINTS:7026.00000
# [103]	train-merror:0.35149	test-merror:0.39421	train-POINTS:29588.00000	test-POINTS:7023.00000
# [104]	train-merror:0.35121	test-merror:0.39440	train-POINTS:29600.00000	test-POINTS:7019.00000
# [105]	train-merror:0.35195	test-merror:0.39421	train-POINTS:29576.00000	test-POINTS:7023.00000
# [106]	train-merror:0.35144	test-merror:0.39458	train-POINTS:29594.00000	test-POINTS:7019.00000
# [107]	train-merror:0.35158	test-merror:0.39403	train-POINTS:29588.00000	test-POINTS:7027.00000
# [108]	train-merror:0.35130	test-merror:0.39440	train-POINTS:29600.00000	test-POINTS:7021.00000
# [109]	train-merror:0.35107	test-merror:0.39532	train-POINTS:29603.00000	test-POINTS:7016.00000
# [110]	train-merror:0.35125	test-merror:0.39569	train-POINTS:29593.00000	test-POINTS:7014.00000
# [111]	train-merror:0.35107	test-merror:0.39550	train-POINTS:29601.00000	test-POINTS:7016.00000
# [112]	train-merror:0.35070	test-merror:0.39606	train-POINTS:29611.00000	test-POINTS:7012.00000
# [113]	train-merror:0.35061	test-merror:0.39624	train-POINTS:29616.00000	test-POINTS:7010.00000
# [114]	train-merror:0.35066	test-merror:0.39550	train-POINTS:29615.00000	test-POINTS:7015.00000
# [115]	train-merror:0.35038	test-merror:0.39550	train-POINTS:29620.00000	test-POINTS:7014.00000
# [116]	train-merror:0.35029	test-merror:0.39587	train-POINTS:29627.00000	test-POINTS:7011.00000
# [117]	train-merror:0.35033	test-merror:0.39569	train-POINTS:29630.00000	test-POINTS:7014.00000
# [118]	train-merror:0.35024	test-merror:0.39661	train-POINTS:29632.00000	test-POINTS:7004.00000
# [119]	train-merror:0.35038	test-merror:0.39587	train-POINTS:29630.00000	test-POINTS:7014.00000
# [120]	train-merror:0.35052	test-merror:0.39624	train-POINTS:29624.00000	test-POINTS:7012.00000
# [121]	train-merror:0.35020	test-merror:0.39624	train-POINTS:29636.00000	test-POINTS:7011.00000
# [122]	train-merror:0.35038	test-merror:0.39661	train-POINTS:29626.00000	test-POINTS:7010.00000
# [123]	train-merror:0.35033	test-merror:0.39643	train-POINTS:29628.00000	test-POINTS:7012.00000
# [124]	train-merror:0.35015	test-merror:0.39624	train-POINTS:29635.00000	test-POINTS:7012.00000
# [125]	train-merror:0.34969	test-merror:0.39624	train-POINTS:29654.00000	test-POINTS:7012.00000
# [126]	train-merror:0.34992	test-merror:0.39606	train-POINTS:29641.00000	test-POINTS:7014.00000
# [127]	train-merror:0.34978	test-merror:0.39550	train-POINTS:29644.00000	test-POINTS:7017.00000
# [128]	train-merror:0.34978	test-merror:0.39606	train-POINTS:29648.00000	test-POINTS:7014.00000
# [129]	train-merror:0.34997	test-merror:0.39606	train-POINTS:29639.00000	test-POINTS:7014.00000
# [130]	train-merror:0.34960	test-merror:0.39679	train-POINTS:29652.00000	test-POINTS:7007.00000
# [131]	train-merror:0.34960	test-merror:0.39643	train-POINTS:29651.00000	test-POINTS:7011.00000
# [132]	train-merror:0.34946	test-merror:0.39550	train-POINTS:29660.00000	test-POINTS:7022.00000
# [133]	train-merror:0.34923	test-merror:0.39643	train-POINTS:29669.00000	test-POINTS:7012.00000
# [134]	train-merror:0.34909	test-merror:0.39661	train-POINTS:29672.00000	test-POINTS:7010.00000
# [135]	train-merror:0.34932	test-merror:0.39606	train-POINTS:29663.00000	test-POINTS:7014.00000
# [136]	train-merror:0.34932	test-merror:0.39587	train-POINTS:29664.00000	test-POINTS:7014.00000
# [137]	train-merror:0.34909	test-merror:0.39606	train-POINTS:29675.00000	test-POINTS:7014.00000
# [138]	train-merror:0.34872	test-merror:0.39606	train-POINTS:29693.00000	test-POINTS:7014.00000
# [139]	train-merror:0.34886	test-merror:0.39569	train-POINTS:29685.00000	test-POINTS:7017.00000
# [140]	train-merror:0.34895	test-merror:0.39606	train-POINTS:29682.00000	test-POINTS:7013.00000
# [141]	train-merror:0.34891	test-merror:0.39624	train-POINTS:29683.00000	test-POINTS:7012.00000
# [142]	train-merror:0.34891	test-merror:0.39587	train-POINTS:29684.00000	test-POINTS:7016.00000
# [143]	train-merror:0.34881	test-merror:0.39587	train-POINTS:29687.00000	test-POINTS:7013.00000
# [144]	train-merror:0.34891	test-merror:0.39606	train-POINTS:29683.00000	test-POINTS:7011.00000
# [145]	train-merror:0.34886	test-merror:0.39550	train-POINTS:29687.00000	test-POINTS:7018.00000
# [146]	train-merror:0.34872	test-merror:0.39514	train-POINTS:29691.00000	test-POINTS:7022.00000
# [147]	train-merror:0.34868	test-merror:0.39550	train-POINTS:29695.00000	test-POINTS:7017.00000
# [148]	train-merror:0.34881	test-merror:0.39587	train-POINTS:29690.00000	test-POINTS:7015.00000
# [149]	train-merror:0.34863	test-merror:0.39587	train-POINTS:29695.00000	test-POINTS:7016.00000
# [150]	train-merror:0.34881	test-merror:0.39550	train-POINTS:29686.00000	test-POINTS:7021.00000
# [151]	train-merror:0.34872	test-merror:0.39569	train-POINTS:29691.00000	test-POINTS:7020.00000
# [152]	train-merror:0.34895	test-merror:0.39550	train-POINTS:29680.00000	test-POINTS:7020.00000
# [153]	train-merror:0.34881	test-merror:0.39550	train-POINTS:29685.00000	test-POINTS:7022.00000
# [154]	train-merror:0.34877	test-merror:0.39550	train-POINTS:29690.00000	test-POINTS:7022.00000
# [155]	train-merror:0.34868	test-merror:0.39587	train-POINTS:29692.00000	test-POINTS:7016.00000
# [156]	train-merror:0.34877	test-merror:0.39606	train-POINTS:29689.00000	test-POINTS:7015.00000
# [157]	train-merror:0.34881	test-merror:0.39679	train-POINTS:29690.00000	test-POINTS:7007.00000
# [158]	train-merror:0.34845	test-merror:0.39624	train-POINTS:29703.00000	test-POINTS:7013.00000
# [159]	train-merror:0.34868	test-merror:0.39606	train-POINTS:29692.00000	test-POINTS:7014.00000
# [160]	train-merror:0.34835	test-merror:0.39606	train-POINTS:29700.00000	test-POINTS:7015.00000
# [161]	train-merror:0.34821	test-merror:0.39606	train-POINTS:29707.00000	test-POINTS:7017.00000
# [162]	train-merror:0.34831	test-merror:0.39569	train-POINTS:29704.00000	test-POINTS:7022.00000
# [163]	train-merror:0.34831	test-merror:0.39569	train-POINTS:29703.00000	test-POINTS:7022.00000
# [164]	train-merror:0.34845	test-merror:0.39569	train-POINTS:29697.00000	test-POINTS:7022.00000
# [165]	train-merror:0.34868	test-merror:0.39587	train-POINTS:29689.00000	test-POINTS:7019.00000
# [166]	train-merror:0.34881	test-merror:0.39624	train-POINTS:29683.00000	test-POINTS:7016.00000
# [167]	train-merror:0.34900	test-merror:0.39606	train-POINTS:29674.00000	test-POINTS:7016.00000
# [168]	train-merror:0.34886	test-merror:0.39606	train-POINTS:29678.00000	test-POINTS:7017.00000
# [169]	train-merror:0.34863	test-merror:0.39550	train-POINTS:29689.00000	test-POINTS:7020.00000
# [170]	train-merror:0.34835	test-merror:0.39532	train-POINTS:29696.00000	test-POINTS:7021.00000
# [171]	train-merror:0.34835	test-merror:0.39495	train-POINTS:29697.00000	test-POINTS:7024.00000
# [172]	train-merror:0.34803	test-merror:0.39514	train-POINTS:29708.00000	test-POINTS:7025.00000
# [173]	train-merror:0.34817	test-merror:0.39587	train-POINTS:29703.00000	test-POINTS:7019.00000
# [174]	train-merror:0.34826	test-merror:0.39569	train-POINTS:29699.00000	test-POINTS:7020.00000
# [175]	train-merror:0.34831	test-merror:0.39569	train-POINTS:29698.00000	test-POINTS:7020.00000
# [176]	train-merror:0.34821	test-merror:0.39587	train-POINTS:29703.00000	test-POINTS:7020.00000
# [177]	train-merror:0.34803	test-merror:0.39606	train-POINTS:29708.00000	test-POINTS:7019.00000
# [178]	train-merror:0.34826	test-merror:0.39587	train-POINTS:29701.00000	test-POINTS:7019.00000
# [179]	train-merror:0.34812	test-merror:0.39532	train-POINTS:29705.00000	test-POINTS:7024.00000
# [180]	train-merror:0.34826	test-merror:0.39532	train-POINTS:29698.00000	test-POINTS:7023.00000
# [181]	train-merror:0.34835	test-merror:0.39550	train-POINTS:29694.00000	test-POINTS:7022.00000
# [182]	train-merror:0.34798	test-merror:0.39532	train-POINTS:29709.00000	test-POINTS:7024.00000
# [183]	train-merror:0.34821	test-merror:0.39550	train-POINTS:29699.00000	test-POINTS:7019.00000
# [184]	train-merror:0.34812	test-merror:0.39587	train-POINTS:29703.00000	test-POINTS:7016.00000
# [185]	train-merror:0.34812	test-merror:0.39624	train-POINTS:29704.00000	test-POINTS:7013.00000
# [186]	train-merror:0.34803	test-merror:0.39624	train-POINTS:29709.00000	test-POINTS:7015.00000
# [187]	train-merror:0.34780	test-merror:0.39624	train-POINTS:29722.00000	test-POINTS:7016.00000
# [188]	train-merror:0.34766	test-merror:0.39606	train-POINTS:29728.00000	test-POINTS:7019.00000
# [189]	train-merror:0.34752	test-merror:0.39606	train-POINTS:29733.00000	test-POINTS:7018.00000
# [190]	train-merror:0.34748	test-merror:0.39606	train-POINTS:29733.00000	test-POINTS:7017.00000
# [191]	train-merror:0.34752	test-merror:0.39643	train-POINTS:29731.00000	test-POINTS:7014.00000
# [192]	train-merror:0.34720	test-merror:0.39624	train-POINTS:29741.00000	test-POINTS:7014.00000
# [193]	train-merror:0.34743	test-merror:0.39679	train-POINTS:29733.00000	test-POINTS:7010.00000
# [194]	train-merror:0.34725	test-merror:0.39698	train-POINTS:29743.00000	test-POINTS:7009.00000
# [195]	train-merror:0.34729	test-merror:0.39661	train-POINTS:29739.00000	test-POINTS:7012.00000
# [196]	train-merror:0.34729	test-merror:0.39643	train-POINTS:29742.00000	test-POINTS:7015.00000
# [197]	train-merror:0.34725	test-merror:0.39624	train-POINTS:29742.00000	test-POINTS:7017.00000
# [198]	train-merror:0.34720	test-merror:0.39569	train-POINTS:29747.00000	test-POINTS:7023.00000
# [199]	train-merror:0.34720	test-merror:0.39587	train-POINTS:29744.00000	test-POINTS:7021.00000
# [200]	train-merror:0.34720	test-merror:0.39569	train-POINTS:29742.00000	test-POINTS:7022.00000
# [201]	train-merror:0.34697	test-merror:0.39532	train-POINTS:29752.00000	test-POINTS:7026.00000
# [202]	train-merror:0.34697	test-merror:0.39550	train-POINTS:29752.00000	test-POINTS:7026.00000
# [203]	train-merror:0.34697	test-merror:0.39550	train-POINTS:29753.00000	test-POINTS:7024.00000
# [204]	train-merror:0.34683	test-merror:0.39514	train-POINTS:29760.00000	test-POINTS:7026.00000
# [205]	train-merror:0.34674	test-merror:0.39495	train-POINTS:29765.00000	test-POINTS:7028.00000
# [206]	train-merror:0.34683	test-merror:0.39477	train-POINTS:29761.00000	test-POINTS:7028.00000
# [207]	train-merror:0.34660	test-merror:0.39440	train-POINTS:29771.00000	test-POINTS:7032.00000
# [208]	train-merror:0.34651	test-merror:0.39477	train-POINTS:29778.00000	test-POINTS:7027.00000
# [209]	train-merror:0.34651	test-merror:0.39458	train-POINTS:29777.00000	test-POINTS:7032.00000
# [210]	train-merror:0.34683	test-merror:0.39440	train-POINTS:29759.00000	test-POINTS:7032.00000
# [211]	train-merror:0.34669	test-merror:0.39440	train-POINTS:29766.00000	test-POINTS:7033.00000
# [212]	train-merror:0.34660	test-merror:0.39440	train-POINTS:29772.00000	test-POINTS:7033.00000
# [213]	train-merror:0.34651	test-merror:0.39421	train-POINTS:29776.00000	test-POINTS:7036.00000
# [214]	train-merror:0.34651	test-merror:0.39421	train-POINTS:29776.00000	test-POINTS:7036.00000
# [215]	train-merror:0.34628	test-merror:0.39440	train-POINTS:29787.00000	test-POINTS:7035.00000
# [216]	train-merror:0.34614	test-merror:0.39440	train-POINTS:29795.00000	test-POINTS:7036.00000
# [217]	train-merror:0.34619	test-merror:0.39458	train-POINTS:29792.00000	test-POINTS:7034.00000
# [218]	train-merror:0.34619	test-merror:0.39421	train-POINTS:29791.00000	test-POINTS:7037.00000
# [219]	train-merror:0.34600	test-merror:0.39458	train-POINTS:29800.00000	test-POINTS:7033.00000
# [220]	train-merror:0.34609	test-merror:0.39440	train-POINTS:29793.00000	test-POINTS:7033.00000
# [221]	train-merror:0.34600	test-merror:0.39440	train-POINTS:29799.00000	test-POINTS:7032.00000
# [222]	train-merror:0.34609	test-merror:0.39440	train-POINTS:29795.00000	test-POINTS:7032.00000
# [223]	train-merror:0.34596	test-merror:0.39440	train-POINTS:29802.00000	test-POINTS:7033.00000
# [224]	train-merror:0.34591	test-merror:0.39477	train-POINTS:29804.00000	test-POINTS:7029.00000
# [225]	train-merror:0.34577	test-merror:0.39495	train-POINTS:29809.00000	test-POINTS:7028.00000
# [226]	train-merror:0.34568	test-merror:0.39495	train-POINTS:29813.00000	test-POINTS:7028.00000
# [227]	train-merror:0.34559	test-merror:0.39514	train-POINTS:29817.00000	test-POINTS:7027.00000
# [228]	train-merror:0.34559	test-merror:0.39495	train-POINTS:29817.00000	test-POINTS:7028.00000
# [229]	train-merror:0.34568	test-merror:0.39458	train-POINTS:29812.00000	test-POINTS:7033.00000
# [230]	train-merror:0.34559	test-merror:0.39514	train-POINTS:29816.00000	test-POINTS:7027.00000
# [231]	train-merror:0.34559	test-merror:0.39495	train-POINTS:29818.00000	test-POINTS:7028.00000
# [232]	train-merror:0.34554	test-merror:0.39477	train-POINTS:29816.00000	test-POINTS:7032.00000
# [233]	train-merror:0.34554	test-merror:0.39421	train-POINTS:29816.00000	test-POINTS:7035.00000
# [234]	train-merror:0.34554	test-merror:0.39421	train-POINTS:29820.00000	test-POINTS:7036.00000
# [235]	train-merror:0.34540	test-merror:0.39458	train-POINTS:29823.00000	test-POINTS:7032.00000
# [236]	train-merror:0.34522	test-merror:0.39495	train-POINTS:29831.00000	test-POINTS:7029.00000
# [237]	train-merror:0.34531	test-merror:0.39514	train-POINTS:29826.00000	test-POINTS:7027.00000
# [238]	train-merror:0.34485	test-merror:0.39440	train-POINTS:29843.00000	test-POINTS:7033.00000
# [239]	train-merror:0.34485	test-merror:0.39384	train-POINTS:29843.00000	test-POINTS:7039.00000
# [240]	train-merror:0.34499	test-merror:0.39458	train-POINTS:29840.00000	test-POINTS:7032.00000
# [241]	train-merror:0.34499	test-merror:0.39421	train-POINTS:29841.00000	test-POINTS:7036.00000
# [242]	train-merror:0.34508	test-merror:0.39384	train-POINTS:29842.00000	test-POINTS:7042.00000
# [243]	train-merror:0.34490	test-merror:0.39421	train-POINTS:29847.00000	test-POINTS:7037.00000
# [244]	train-merror:0.34485	test-merror:0.39458	train-POINTS:29847.00000	test-POINTS:7033.00000
# [245]	train-merror:0.34504	test-merror:0.39458	train-POINTS:29840.00000	test-POINTS:7032.00000
# [246]	train-merror:0.34494	test-merror:0.39458	train-POINTS:29844.00000	test-POINTS:7033.00000
# [247]	train-merror:0.34504	test-merror:0.39477	train-POINTS:29842.00000	test-POINTS:7031.00000
# [248]	train-merror:0.34508	test-merror:0.39495	train-POINTS:29838.00000	test-POINTS:7030.00000
# [249]	train-merror:0.34490	test-merror:0.39477	train-POINTS:29850.00000	test-POINTS:7029.00000
# [250]	train-merror:0.34480	test-merror:0.39495	train-POINTS:29851.00000	test-POINTS:7028.00000
# [251]	train-merror:0.34471	test-merror:0.39477	train-POINTS:29856.00000	test-POINTS:7030.00000
# [252]	train-merror:0.34439	test-merror:0.39495	train-POINTS:29867.00000	test-POINTS:7027.00000
# [253]	train-merror:0.34435	test-merror:0.39495	train-POINTS:29869.00000	test-POINTS:7027.00000
# [254]	train-merror:0.34411	test-merror:0.39421	train-POINTS:29875.00000	test-POINTS:7034.00000
# [255]	train-merror:0.34407	test-merror:0.39440	train-POINTS:29878.00000	test-POINTS:7033.00000
# [256]	train-merror:0.34361	test-merror:0.39440	train-POINTS:29899.00000	test-POINTS:7033.00000
# [257]	train-merror:0.34342	test-merror:0.39421	train-POINTS:29906.00000	test-POINTS:7035.00000
# [258]	train-merror:0.34342	test-merror:0.39421	train-POINTS:29907.00000	test-POINTS:7035.00000
# [259]	train-merror:0.34333	test-merror:0.39440	train-POINTS:29911.00000	test-POINTS:7033.00000
# [260]	train-merror:0.34324	test-merror:0.39477	train-POINTS:29914.00000	test-POINTS:7030.00000
# [261]	train-merror:0.34319	test-merror:0.39477	train-POINTS:29916.00000	test-POINTS:7030.00000
# [262]	train-merror:0.34324	test-merror:0.39458	train-POINTS:29912.00000	test-POINTS:7032.00000
# [263]	train-merror:0.34301	test-merror:0.39458	train-POINTS:29925.00000	test-POINTS:7032.00000
# [264]	train-merror:0.34324	test-merror:0.39458	train-POINTS:29913.00000	test-POINTS:7032.00000
# [265]	train-merror:0.34324	test-merror:0.39440	train-POINTS:29912.00000	test-POINTS:7034.00000
# [266]	train-merror:0.34315	test-merror:0.39477	train-POINTS:29916.00000	test-POINTS:7030.00000
# [267]	train-merror:0.34301	test-merror:0.39495	train-POINTS:29920.00000	test-POINTS:7028.00000
# [268]	train-merror:0.34319	test-merror:0.39477	train-POINTS:29914.00000	test-POINTS:7029.00000
# [269]	train-merror:0.34329	test-merror:0.39458	train-POINTS:29912.00000	test-POINTS:7031.00000
# [270]	train-merror:0.34315	test-merror:0.39495	train-POINTS:29918.00000	test-POINTS:7027.00000
# [271]	train-merror:0.34282	test-merror:0.39495	train-POINTS:29928.00000	test-POINTS:7027.00000
# [272]	train-merror:0.34269	test-merror:0.39495	train-POINTS:29936.00000	test-POINTS:7028.00000
# [273]	train-merror:0.34278	test-merror:0.39458	train-POINTS:29930.00000	test-POINTS:7031.00000
# [274]	train-merror:0.34296	test-merror:0.39458	train-POINTS:29923.00000	test-POINTS:7031.00000
# [275]	train-merror:0.34278	test-merror:0.39440	train-POINTS:29929.00000	test-POINTS:7033.00000
# [276]	train-merror:0.34301	test-merror:0.39477	train-POINTS:29919.00000	test-POINTS:7029.00000
# [277]	train-merror:0.34292	test-merror:0.39477	train-POINTS:29925.00000	test-POINTS:7029.00000
# [278]	train-merror:0.34278	test-merror:0.39477	train-POINTS:29931.00000	test-POINTS:7029.00000
# [279]	train-merror:0.34315	test-merror:0.39477	train-POINTS:29917.00000	test-POINTS:7029.00000
# [280]	train-merror:0.34292	test-merror:0.39477	train-POINTS:29926.00000	test-POINTS:7028.00000
# [281]	train-merror:0.34269	test-merror:0.39514	train-POINTS:29934.00000	test-POINTS:7025.00000
# [282]	train-merror:0.34278	test-merror:0.39532	train-POINTS:29933.00000	test-POINTS:7026.00000
# [283]	train-merror:0.34255	test-merror:0.39532	train-POINTS:29942.00000	test-POINTS:7026.00000
# [284]	train-merror:0.34264	test-merror:0.39532	train-POINTS:29937.00000	test-POINTS:7026.00000
# [285]	train-merror:0.34255	test-merror:0.39532	train-POINTS:29942.00000	test-POINTS:7025.00000
# [286]	train-merror:0.34255	test-merror:0.39514	train-POINTS:29944.00000	test-POINTS:7027.00000
# [287]	train-merror:0.34255	test-merror:0.39532	train-POINTS:29944.00000	test-POINTS:7023.00000
# [288]	train-merror:0.34218	test-merror:0.39514	train-POINTS:29958.00000	test-POINTS:7025.00000
# [289]	train-merror:0.34236	test-merror:0.39532	train-POINTS:29952.00000	test-POINTS:7024.00000
# [290]	train-merror:0.34241	test-merror:0.39532	train-POINTS:29949.00000	test-POINTS:7024.00000
# [291]	train-merror:0.34250	test-merror:0.39495	train-POINTS:29943.00000	test-POINTS:7027.00000
# [292]	train-merror:0.34236	test-merror:0.39514	train-POINTS:29952.00000	test-POINTS:7026.00000
# [293]	train-merror:0.34209	test-merror:0.39514	train-POINTS:29966.00000	test-POINTS:7027.00000
# [294]	train-merror:0.34218	test-merror:0.39569	train-POINTS:29960.00000	test-POINTS:7021.00000
# [295]	train-merror:0.34181	test-merror:0.39550	train-POINTS:29975.00000	test-POINTS:7024.00000
# [296]	train-merror:0.34158	test-merror:0.39550	train-POINTS:29983.00000	test-POINTS:7024.00000
# [297]	train-merror:0.34149	test-merror:0.39514	train-POINTS:29987.00000	test-POINTS:7027.00000
# [298]	train-merror:0.34144	test-merror:0.39495	train-POINTS:29990.00000	test-POINTS:7030.00000
# [299]	train-merror:0.34172	test-merror:0.39495	train-POINTS:29980.00000	test-POINTS:7028.00000
# [300]	train-merror:0.34172	test-merror:0.39514	train-POINTS:29980.00000	test-POINTS:7027.00000
# [301]	train-merror:0.34176	test-merror:0.39495	train-POINTS:29978.00000	test-POINTS:7029.00000
# [302]	train-merror:0.34167	test-merror:0.39495	train-POINTS:29983.00000	test-POINTS:7029.00000
# [303]	train-merror:0.34167	test-merror:0.39477	train-POINTS:29983.00000	test-POINTS:7030.00000
# [304]	train-merror:0.34140	test-merror:0.39477	train-POINTS:29990.00000	test-POINTS:7030.00000
# [305]	train-merror:0.34158	test-merror:0.39458	train-POINTS:29986.00000	test-POINTS:7031.00000
# [306]	train-merror:0.34158	test-merror:0.39532	train-POINTS:29986.00000	test-POINTS:7025.00000
# [307]	train-merror:0.34135	test-merror:0.39514	train-POINTS:29994.00000	test-POINTS:7027.00000
# [308]	train-merror:0.34153	test-merror:0.39458	train-POINTS:29984.00000	test-POINTS:7032.00000
# [309]	train-merror:0.34140	test-merror:0.39514	train-POINTS:29991.00000	test-POINTS:7027.00000
# [310]	train-merror:0.34126	test-merror:0.39477	train-POINTS:29997.00000	test-POINTS:7029.00000
# [311]	train-merror:0.34093	test-merror:0.39458	train-POINTS:30012.00000	test-POINTS:7031.00000
# [312]	train-merror:0.34103	test-merror:0.39440	train-POINTS:30009.00000	test-POINTS:7032.00000
# [313]	train-merror:0.34089	test-merror:0.39458	train-POINTS:30010.00000	test-POINTS:7032.00000
# [314]	train-merror:0.34075	test-merror:0.39458	train-POINTS:30016.00000	test-POINTS:7031.00000
# [315]	train-merror:0.34070	test-merror:0.39421	train-POINTS:30017.00000	test-POINTS:7034.00000
# [316]	train-merror:0.34061	test-merror:0.39421	train-POINTS:30022.00000	test-POINTS:7034.00000
# [317]	train-merror:0.34070	test-merror:0.39477	train-POINTS:30016.00000	test-POINTS:7030.00000
# [318]	train-merror:0.34052	test-merror:0.39495	train-POINTS:30026.00000	test-POINTS:7027.00000
# [319]	train-merror:0.34043	test-merror:0.39514	train-POINTS:30030.00000	test-POINTS:7026.00000
# [320]	train-merror:0.34057	test-merror:0.39514	train-POINTS:30026.00000	test-POINTS:7026.00000
# [321]	train-merror:0.34029	test-merror:0.39532	train-POINTS:30038.00000	test-POINTS:7024.00000
# [322]	train-merror:0.34011	test-merror:0.39532	train-POINTS:30046.00000	test-POINTS:7024.00000
# [323]	train-merror:0.34024	test-merror:0.39514	train-POINTS:30042.00000	test-POINTS:7025.00000
# [324]	train-merror:0.34029	test-merror:0.39495	train-POINTS:30039.00000	test-POINTS:7026.00000
# [325]	train-merror:0.34024	test-merror:0.39550	train-POINTS:30041.00000	test-POINTS:7021.00000
# [326]	train-merror:0.34034	test-merror:0.39495	train-POINTS:30037.00000	test-POINTS:7026.00000
# [327]	train-merror:0.34024	test-merror:0.39477	train-POINTS:30039.00000	test-POINTS:7029.00000
# [328]	train-merror:0.34029	test-merror:0.39477	train-POINTS:30038.00000	test-POINTS:7028.00000
# [329]	train-merror:0.34043	test-merror:0.39458	train-POINTS:30030.00000	test-POINTS:7029.00000
# [330]	train-merror:0.34034	test-merror:0.39440	train-POINTS:30034.00000	test-POINTS:7031.00000
# [331]	train-merror:0.34029	test-merror:0.39421	train-POINTS:30034.00000	test-POINTS:7034.00000
# [332]	train-merror:0.34011	test-merror:0.39421	train-POINTS:30041.00000	test-POINTS:7033.00000
# [333]	train-merror:0.33978	test-merror:0.39458	train-POINTS:30057.00000	test-POINTS:7029.00000
# [334]	train-merror:0.33992	test-merror:0.39440	train-POINTS:30051.00000	test-POINTS:7032.00000
# [335]	train-merror:0.33983	test-merror:0.39440	train-POINTS:30054.00000	test-POINTS:7034.00000
# [336]	train-merror:0.33978	test-merror:0.39421	train-POINTS:30057.00000	test-POINTS:7035.00000
# [337]	train-merror:0.33978	test-merror:0.39403	train-POINTS:30057.00000	test-POINTS:7035.00000
# [338]	train-merror:0.33974	test-merror:0.39421	train-POINTS:30060.00000	test-POINTS:7035.00000
# [339]	train-merror:0.33988	test-merror:0.39421	train-POINTS:30055.00000	test-POINTS:7038.00000
# [340]	train-merror:0.33983	test-merror:0.39440	train-POINTS:30056.00000	test-POINTS:7036.00000
# [341]	train-merror:0.33951	test-merror:0.39421	train-POINTS:30067.00000	test-POINTS:7036.00000
# [342]	train-merror:0.33951	test-merror:0.39440	train-POINTS:30068.00000	test-POINTS:7036.00000
# [343]	train-merror:0.33951	test-merror:0.39495	train-POINTS:30070.00000	test-POINTS:7029.00000
# [344]	train-merror:0.33928	test-merror:0.39569	train-POINTS:30077.00000	test-POINTS:7022.00000
# [345]	train-merror:0.33946	test-merror:0.39550	train-POINTS:30070.00000	test-POINTS:7024.00000
# [346]	train-merror:0.33951	test-merror:0.39495	train-POINTS:30068.00000	test-POINTS:7030.00000
# [347]	train-merror:0.33932	test-merror:0.39532	train-POINTS:30077.00000	test-POINTS:7029.00000
# [348]	train-merror:0.33932	test-merror:0.39495	train-POINTS:30077.00000	test-POINTS:7032.00000
# [349]	train-merror:0.33923	test-merror:0.39495	train-POINTS:30080.00000	test-POINTS:7032.00000
# [350]	train-merror:0.33914	test-merror:0.39514	train-POINTS:30081.00000	test-POINTS:7031.00000
# [351]	train-merror:0.33891	test-merror:0.39477	train-POINTS:30088.00000	test-POINTS:7035.00000
# [352]	train-merror:0.33900	test-merror:0.39495	train-POINTS:30084.00000	test-POINTS:7033.00000
# [353]	train-merror:0.33882	test-merror:0.39458	train-POINTS:30092.00000	test-POINTS:7035.00000
# [354]	train-merror:0.33882	test-merror:0.39440	train-POINTS:30091.00000	test-POINTS:7036.00000
# [355]	train-merror:0.33872	test-merror:0.39440	train-POINTS:30096.00000	test-POINTS:7036.00000
# [356]	train-merror:0.33882	test-merror:0.39440	train-POINTS:30089.00000	test-POINTS:7036.00000
# [357]	train-merror:0.33882	test-merror:0.39421	train-POINTS:30087.00000	test-POINTS:7037.00000
# [358]	train-merror:0.33859	test-merror:0.39421	train-POINTS:30096.00000	test-POINTS:7036.00000
# [359]	train-merror:0.33849	test-merror:0.39458	train-POINTS:30100.00000	test-POINTS:7033.00000
# [360]	train-merror:0.33813	test-merror:0.39532	train-POINTS:30115.00000	test-POINTS:7028.00000
# [361]	train-merror:0.33836	test-merror:0.39532	train-POINTS:30107.00000	test-POINTS:7028.00000
# [362]	train-merror:0.33817	test-merror:0.39514	train-POINTS:30113.00000	test-POINTS:7031.00000
# [363]	train-merror:0.33817	test-merror:0.39569	train-POINTS:30113.00000	test-POINTS:7025.00000
# [364]	train-merror:0.33794	test-merror:0.39587	train-POINTS:30124.00000	test-POINTS:7022.00000
# [365]	train-merror:0.33808	test-merror:0.39587	train-POINTS:30117.00000	test-POINTS:7022.00000
# [366]	train-merror:0.33817	test-merror:0.39569	train-POINTS:30113.00000	test-POINTS:7024.00000
# [367]	train-merror:0.33826	test-merror:0.39550	train-POINTS:30113.00000	test-POINTS:7026.00000
# [368]	train-merror:0.33799	test-merror:0.39606	train-POINTS:30124.00000	test-POINTS:7020.00000
# [369]	train-merror:0.33789	test-merror:0.39606	train-POINTS:30129.00000	test-POINTS:7019.00000
# [370]	train-merror:0.33776	test-merror:0.39514	train-POINTS:30135.00000	test-POINTS:7027.00000
# [371]	train-merror:0.33799	test-merror:0.39550	train-POINTS:30126.00000	test-POINTS:7025.00000
# [372]	train-merror:0.33771	test-merror:0.39606	train-POINTS:30137.00000	test-POINTS:7022.00000
# [373]	train-merror:0.33762	test-merror:0.39569	train-POINTS:30141.00000	test-POINTS:7025.00000
# [374]	train-merror:0.33766	test-merror:0.39587	train-POINTS:30141.00000	test-POINTS:7023.00000
# [375]	train-merror:0.33780	test-merror:0.39606	train-POINTS:30136.00000	test-POINTS:7022.00000
# [376]	train-merror:0.33780	test-merror:0.39569	train-POINTS:30134.00000	test-POINTS:7025.00000
# [377]	train-merror:0.33780	test-merror:0.39569	train-POINTS:30135.00000	test-POINTS:7026.00000
# [378]	train-merror:0.33780	test-merror:0.39569	train-POINTS:30135.00000	test-POINTS:7026.00000
# [379]	train-merror:0.33766	test-merror:0.39569	train-POINTS:30140.00000	test-POINTS:7025.00000
# [380]	train-merror:0.33762	test-merror:0.39606	train-POINTS:30141.00000	test-POINTS:7023.00000
# [381]	train-merror:0.33771	test-merror:0.39569	train-POINTS:30139.00000	test-POINTS:7027.00000
# [382]	train-merror:0.33757	test-merror:0.39550	train-POINTS:30141.00000	test-POINTS:7027.00000
# [383]	train-merror:0.33753	test-merror:0.39477	train-POINTS:30144.00000	test-POINTS:7033.00000
# [384]	train-merror:0.33743	test-merror:0.39532	train-POINTS:30146.00000	test-POINTS:7030.00000
# [385]	train-merror:0.33771	test-merror:0.39514	train-POINTS:30138.00000	test-POINTS:7031.00000
# [386]	train-merror:0.33739	test-merror:0.39550	train-POINTS:30154.00000	test-POINTS:7027.00000
# [387]	train-merror:0.33734	test-merror:0.39550	train-POINTS:30156.00000	test-POINTS:7026.00000
# [388]	train-merror:0.33725	test-merror:0.39569	train-POINTS:30159.00000	test-POINTS:7026.00000
# [389]	train-merror:0.33711	test-merror:0.39569	train-POINTS:30164.00000	test-POINTS:7026.00000
# [390]	train-merror:0.33688	test-merror:0.39624	train-POINTS:30172.00000	test-POINTS:7021.00000
# [391]	train-merror:0.33707	test-merror:0.39606	train-POINTS:30163.00000	test-POINTS:7024.00000
# [392]	train-merror:0.33697	test-merror:0.39587	train-POINTS:30164.00000	test-POINTS:7026.00000
# [393]	train-merror:0.33697	test-merror:0.39606	train-POINTS:30164.00000	test-POINTS:7024.00000
# [394]	train-merror:0.33702	test-merror:0.39587	train-POINTS:30164.00000	test-POINTS:7025.00000
# [395]	train-merror:0.33683	test-merror:0.39550	train-POINTS:30169.00000	test-POINTS:7029.00000
# [396]	train-merror:0.33674	test-merror:0.39587	train-POINTS:30175.00000	test-POINTS:7025.00000
# [397]	train-merror:0.33665	test-merror:0.39550	train-POINTS:30180.00000	test-POINTS:7029.00000
# [398]	train-merror:0.33674	test-merror:0.39569	train-POINTS:30174.00000	test-POINTS:7027.00000
# [399]	train-merror:0.33670	test-merror:0.39514	train-POINTS:30176.00000	test-POINTS:7032.00000
# [400]	train-merror:0.33660	test-merror:0.39495	train-POINTS:30179.00000	test-POINTS:7034.00000
# [401]	train-merror:0.33665	test-merror:0.39458	train-POINTS:30175.00000	test-POINTS:7037.00000
# [402]	train-merror:0.33642	test-merror:0.39458	train-POINTS:30185.00000	test-POINTS:7037.00000
# [403]	train-merror:0.33637	test-merror:0.39514	train-POINTS:30189.00000	test-POINTS:7032.00000
# [404]	train-merror:0.33637	test-merror:0.39495	train-POINTS:30189.00000	test-POINTS:7034.00000
# [405]	train-merror:0.33633	test-merror:0.39495	train-POINTS:30193.00000	test-POINTS:7033.00000
# [406]	train-merror:0.33637	test-merror:0.39477	train-POINTS:30192.00000	test-POINTS:7035.00000
# [407]	train-merror:0.33619	test-merror:0.39477	train-POINTS:30201.00000	test-POINTS:7036.00000
# [408]	train-merror:0.33628	test-merror:0.39514	train-POINTS:30198.00000	test-POINTS:7031.00000
# [409]	train-merror:0.33619	test-merror:0.39514	train-POINTS:30201.00000	test-POINTS:7031.00000
# [410]	train-merror:0.33614	test-merror:0.39532	train-POINTS:30202.00000	test-POINTS:7029.00000
# [411]	train-merror:0.33614	test-merror:0.39440	train-POINTS:30200.00000	test-POINTS:7036.00000
# [412]	train-merror:0.33605	test-merror:0.39440	train-POINTS:30205.00000	test-POINTS:7037.00000
# [413]	train-merror:0.33596	test-merror:0.39458	train-POINTS:30209.00000	test-POINTS:7036.00000
# [414]	train-merror:0.33587	test-merror:0.39421	train-POINTS:30213.00000	test-POINTS:7039.00000
# [415]	train-merror:0.33564	test-merror:0.39477	train-POINTS:30221.00000	test-POINTS:7032.00000
# [416]	train-merror:0.33577	test-merror:0.39495	train-POINTS:30216.00000	test-POINTS:7030.00000
# [417]	train-merror:0.33568	test-merror:0.39477	train-POINTS:30217.00000	test-POINTS:7032.00000
# [418]	train-merror:0.33559	test-merror:0.39458	train-POINTS:30220.00000	test-POINTS:7035.00000
# [419]	train-merror:0.33550	test-merror:0.39495	train-POINTS:30224.00000	test-POINTS:7031.00000
# [420]	train-merror:0.33568	test-merror:0.39440	train-POINTS:30214.00000	test-POINTS:7036.00000
# [421]	train-merror:0.33577	test-merror:0.39477	train-POINTS:30212.00000	test-POINTS:7032.00000
# [422]	train-merror:0.33582	test-merror:0.39514	train-POINTS:30210.00000	test-POINTS:7029.00000
# [423]	train-merror:0.33573	test-merror:0.39514	train-POINTS:30214.00000	test-POINTS:7030.00000
# [424]	train-merror:0.33564	test-merror:0.39514	train-POINTS:30218.00000	test-POINTS:7029.00000
# [425]	train-merror:0.33559	test-merror:0.39514	train-POINTS:30218.00000	test-POINTS:7029.00000
# [426]	train-merror:0.33568	test-merror:0.39550	train-POINTS:30216.00000	test-POINTS:7026.00000
# [427]	train-merror:0.33564	test-merror:0.39550	train-POINTS:30220.00000	test-POINTS:7027.00000
# [428]	train-merror:0.33550	test-merror:0.39495	train-POINTS:30226.00000	test-POINTS:7030.00000
# [429]	train-merror:0.33545	test-merror:0.39495	train-POINTS:30227.00000	test-POINTS:7031.00000
# [430]	train-merror:0.33545	test-merror:0.39477	train-POINTS:30227.00000	test-POINTS:7033.00000
# [431]	train-merror:0.33554	test-merror:0.39458	train-POINTS:30224.00000	test-POINTS:7034.00000
# [432]	train-merror:0.33541	test-merror:0.39440	train-POINTS:30231.00000	test-POINTS:7037.00000
# [433]	train-merror:0.33559	test-merror:0.39421	train-POINTS:30224.00000	test-POINTS:7038.00000
# [434]	train-merror:0.33550	test-merror:0.39384	train-POINTS:30226.00000	test-POINTS:7041.00000
# [435]	train-merror:0.33550	test-merror:0.39421	train-POINTS:30231.00000	test-POINTS:7039.00000
# [436]	train-merror:0.33527	test-merror:0.39403	train-POINTS:30239.00000	test-POINTS:7042.00000
# [437]	train-merror:0.33513	test-merror:0.39440	train-POINTS:30242.00000	test-POINTS:7039.00000
# [438]	train-merror:0.33522	test-merror:0.39458	train-POINTS:30239.00000	test-POINTS:7038.00000
# [439]	train-merror:0.33536	test-merror:0.39458	train-POINTS:30234.00000	test-POINTS:7038.00000
# [440]	train-merror:0.33513	test-merror:0.39421	train-POINTS:30244.00000	test-POINTS:7040.00000
# [441]	train-merror:0.33513	test-merror:0.39421	train-POINTS:30244.00000	test-POINTS:7040.00000
# [442]	train-merror:0.33527	test-merror:0.39403	train-POINTS:30240.00000	test-POINTS:7042.00000
# [443]	train-merror:0.33508	test-merror:0.39384	train-POINTS:30247.00000	test-POINTS:7043.00000
# [444]	train-merror:0.33485	test-merror:0.39384	train-POINTS:30255.00000	test-POINTS:7044.00000
# [445]	train-merror:0.33485	test-merror:0.39366	train-POINTS:30255.00000	test-POINTS:7045.00000
# [446]	train-merror:0.33485	test-merror:0.39403	train-POINTS:30255.00000	test-POINTS:7044.00000
# [447]	train-merror:0.33499	test-merror:0.39421	train-POINTS:30250.00000	test-POINTS:7041.00000
# [448]	train-merror:0.33476	test-merror:0.39403	train-POINTS:30260.00000	test-POINTS:7043.00000
# [449]	train-merror:0.33453	test-merror:0.39403	train-POINTS:30271.00000	test-POINTS:7044.00000
# [450]	train-merror:0.33462	test-merror:0.39421	train-POINTS:30266.00000	test-POINTS:7042.00000
# [451]	train-merror:0.33467	test-merror:0.39403	train-POINTS:30263.00000	test-POINTS:7044.00000
# [452]	train-merror:0.33472	test-merror:0.39421	train-POINTS:30262.00000	test-POINTS:7042.00000
# [453]	train-merror:0.33467	test-merror:0.39403	train-POINTS:30265.00000	test-POINTS:7043.00000
# [454]	train-merror:0.33458	test-merror:0.39458	train-POINTS:30267.00000	test-POINTS:7037.00000
# [455]	train-merror:0.33448	test-merror:0.39440	train-POINTS:30270.00000	test-POINTS:7039.00000
# [456]	train-merror:0.33453	test-merror:0.39458	train-POINTS:30266.00000	test-POINTS:7037.00000
# [457]	train-merror:0.33453	test-merror:0.39458	train-POINTS:30266.00000	test-POINTS:7037.00000
# [458]	train-merror:0.33430	test-merror:0.39458	train-POINTS:30277.00000	test-POINTS:7037.00000
# [459]	train-merror:0.33407	test-merror:0.39495	train-POINTS:30286.00000	test-POINTS:7035.00000
# [460]	train-merror:0.33398	test-merror:0.39495	train-POINTS:30291.00000	test-POINTS:7035.00000
# [461]	train-merror:0.33389	test-merror:0.39495	train-POINTS:30295.00000	test-POINTS:7035.00000
# [462]	train-merror:0.33398	test-merror:0.39477	train-POINTS:30290.00000	test-POINTS:7037.00000
# [463]	train-merror:0.33416	test-merror:0.39495	train-POINTS:30284.00000	test-POINTS:7036.00000
# [464]	train-merror:0.33402	test-merror:0.39495	train-POINTS:30284.00000	test-POINTS:7036.00000
# [465]	train-merror:0.33370	test-merror:0.39477	train-POINTS:30298.00000	test-POINTS:7037.00000
# [466]	train-merror:0.33361	test-merror:0.39495	train-POINTS:30303.00000	test-POINTS:7037.00000
# [467]	train-merror:0.33324	test-merror:0.39477	train-POINTS:30318.00000	test-POINTS:7038.00000
# [468]	train-merror:0.33320	test-merror:0.39495	train-POINTS:30319.00000	test-POINTS:7036.00000
# [469]	train-merror:0.33320	test-merror:0.39514	train-POINTS:30322.00000	test-POINTS:7035.00000
# [470]	train-merror:0.33324	test-merror:0.39532	train-POINTS:30320.00000	test-POINTS:7034.00000
# [471]	train-merror:0.33320	test-merror:0.39458	train-POINTS:30322.00000	test-POINTS:7042.00000
# [472]	train-merror:0.33329	test-merror:0.39458	train-POINTS:30317.00000	test-POINTS:7041.00000
# [473]	train-merror:0.33320	test-merror:0.39477	train-POINTS:30318.00000	test-POINTS:7039.00000
# [474]	train-merror:0.33315	test-merror:0.39458	train-POINTS:30322.00000	test-POINTS:7041.00000
# [475]	train-merror:0.33320	test-merror:0.39458	train-POINTS:30319.00000	test-POINTS:7040.00000
# [476]	train-merror:0.33315	test-merror:0.39458	train-POINTS:30322.00000	test-POINTS:7039.00000
# [477]	train-merror:0.33320	test-merror:0.39458	train-POINTS:30321.00000	test-POINTS:7039.00000
# [478]	train-merror:0.33320	test-merror:0.39458	train-POINTS:30318.00000	test-POINTS:7039.00000
# [479]	train-merror:0.33292	test-merror:0.39458	train-POINTS:30330.00000	test-POINTS:7038.00000
# [480]	train-merror:0.33273	test-merror:0.39458	train-POINTS:30335.00000	test-POINTS:7037.00000
# [481]	train-merror:0.33297	test-merror:0.39495	train-POINTS:30325.00000	test-POINTS:7034.00000
# [482]	train-merror:0.33283	test-merror:0.39495	train-POINTS:30330.00000	test-POINTS:7034.00000
# [483]	train-merror:0.33287	test-merror:0.39514	train-POINTS:30327.00000	test-POINTS:7033.00000
# [484]	train-merror:0.33273	test-merror:0.39514	train-POINTS:30333.00000	test-POINTS:7034.00000
# [485]	train-merror:0.33269	test-merror:0.39514	train-POINTS:30336.00000	test-POINTS:7032.00000
# [486]	train-merror:0.33264	test-merror:0.39514	train-POINTS:30339.00000	test-POINTS:7032.00000
# [487]	train-merror:0.33227	test-merror:0.39477	train-POINTS:30355.00000	test-POINTS:7036.00000
# [488]	train-merror:0.33241	test-merror:0.39458	train-POINTS:30348.00000	test-POINTS:7037.00000
# [489]	train-merror:0.33218	test-merror:0.39477	train-POINTS:30358.00000	test-POINTS:7037.00000
# [490]	train-merror:0.33209	test-merror:0.39495	train-POINTS:30362.00000	test-POINTS:7037.00000
# [491]	train-merror:0.33218	test-merror:0.39514	train-POINTS:30358.00000	test-POINTS:7035.00000
# [492]	train-merror:0.33214	test-merror:0.39514	train-POINTS:30361.00000	test-POINTS:7034.00000
# [493]	train-merror:0.33204	test-merror:0.39532	train-POINTS:30365.00000	test-POINTS:7032.00000
# [494]	train-merror:0.33204	test-merror:0.39514	train-POINTS:30363.00000	test-POINTS:7034.00000
# [495]	train-merror:0.33191	test-merror:0.39477	train-POINTS:30370.00000	test-POINTS:7038.00000
# [496]	train-merror:0.33200	test-merror:0.39532	train-POINTS:30366.00000	test-POINTS:7033.00000
# [497]	train-merror:0.33195	test-merror:0.39550	train-POINTS:30369.00000	test-POINTS:7031.00000
# [498]	train-merror:0.33163	test-merror:0.39587	train-POINTS:30381.00000	test-POINTS:7028.00000
# [499]	train-merror:0.33163	test-merror:0.39532	train-POINTS:30381.00000	test-POINTS:7033.00000
# [500]	train-merror:0.33158	test-merror:0.39550	train-POINTS:30379.00000	test-POINTS:7031.00000
# [501]	train-merror:0.33163	test-merror:0.39550	train-POINTS:30378.00000	test-POINTS:7030.00000
# [502]	train-merror:0.33144	test-merror:0.39514	train-POINTS:30385.00000	test-POINTS:7035.00000
# [503]	train-merror:0.33144	test-merror:0.39458	train-POINTS:30387.00000	test-POINTS:7039.00000
# [504]	train-merror:0.33154	test-merror:0.39421	train-POINTS:30384.00000	test-POINTS:7042.00000
# [505]	train-merror:0.33144	test-merror:0.39477	train-POINTS:30386.00000	test-POINTS:7037.00000
# ...
# [1234]	train-merror:0.28514	test-merror:0.38868	train-POINTS:32170.00000	test-POINTS:7101.00000
# [1235]	train-merror:0.28514	test-merror:0.38905	train-POINTS:32170.00000	test-POINTS:7097.00000
# [1236]	train-merror:0.28500	test-merror:0.38905	train-POINTS:32176.00000	test-POINTS:7097.00000
# [1237]	train-merror:0.28500	test-merror:0.38905	train-POINTS:32175.00000	test-POINTS:7098.00000
# [1238]	train-merror:0.28486	test-merror:0.38905	train-POINTS:32181.00000	test-POINTS:7098.00000
# [1239]	train-merror:0.28468	test-merror:0.38868	train-POINTS:32185.00000	test-POINTS:7101.00000
# [1240]	train-merror:0.28468	test-merror:0.38887	train-POINTS:32185.00000	test-POINTS:7099.00000
# [1241]	train-merror:0.28454	test-merror:0.38887	train-POINTS:32190.00000	test-POINTS:7098.00000
# [1242]	train-merror:0.28454	test-merror:0.38942	train-POINTS:32188.00000	test-POINTS:7093.00000
# [1243]	train-merror:0.28422	test-merror:0.38924	train-POINTS:32201.00000	test-POINTS:7096.00000
# [1244]	train-merror:0.28431	test-merror:0.38868	train-POINTS:32200.00000	test-POINTS:7102.00000
# [1245]	train-merror:0.28413	test-merror:0.38832	train-POINTS:32206.00000	test-POINTS:7105.00000
# [1246]	train-merror:0.28413	test-merror:0.38832	train-POINTS:32205.00000	test-POINTS:7105.00000
# [1247]	train-merror:0.28399	test-merror:0.38868	train-POINTS:32212.00000	test-POINTS:7102.00000
# [1248]	train-merror:0.28394	test-merror:0.38868	train-POINTS:32214.00000	test-POINTS:7101.00000
# [1249]	train-merror:0.28381	test-merror:0.38905	train-POINTS:32219.00000	test-POINTS:7098.00000
# [1250]	train-merror:0.28371	test-merror:0.38868	train-POINTS:32223.00000	test-POINTS:7101.00000
# [1251]	train-merror:0.28381	test-merror:0.38850	train-POINTS:32220.00000	test-POINTS:7103.00000
# [1252]	train-merror:0.28376	test-merror:0.38887	train-POINTS:32222.00000	test-POINTS:7100.00000
# [1253]	train-merror:0.28358	test-merror:0.38924	train-POINTS:32228.00000	test-POINTS:7097.00000
# [1254]	train-merror:0.28348	test-merror:0.38924	train-POINTS:32231.00000	test-POINTS:7096.00000
# [1255]	train-merror:0.28348	test-merror:0.38905	train-POINTS:32231.00000	test-POINTS:7098.00000
# [1256]	train-merror:0.28335	test-merror:0.38924	train-POINTS:32235.00000	test-POINTS:7096.00000
# [1257]	train-merror:0.28321	test-merror:0.38942	train-POINTS:32243.00000	test-POINTS:7094.00000
# [1258]	train-merror:0.28302	test-merror:0.38961	train-POINTS:32245.00000	test-POINTS:7092.00000
# [1259]	train-merror:0.28311	test-merror:0.38905	train-POINTS:32243.00000	test-POINTS:7095.00000
# [1260]	train-merror:0.28302	test-merror:0.38905	train-POINTS:32245.00000	test-POINTS:7095.00000
# [1261]	train-merror:0.28288	test-merror:0.38924	train-POINTS:32250.00000	test-POINTS:7094.00000
# [1262]	train-merror:0.28279	test-merror:0.38905	train-POINTS:32255.00000	test-POINTS:7094.00000
# [1263]	train-merror:0.28279	test-merror:0.38868	train-POINTS:32257.00000	test-POINTS:7099.00000
# [1264]	train-merror:0.28279	test-merror:0.38887	train-POINTS:32255.00000	test-POINTS:7098.00000
# [1265]	train-merror:0.28279	test-merror:0.38905	train-POINTS:32256.00000	test-POINTS:7096.00000
# [1266]	train-merror:0.28275	test-merror:0.38887	train-POINTS:32255.00000	test-POINTS:7098.00000
# [1267]	train-merror:0.28242	test-merror:0.38887	train-POINTS:32268.00000	test-POINTS:7098.00000
# [1268]	train-merror:0.28265	test-merror:0.38887	train-POINTS:32259.00000	test-POINTS:7098.00000
# [1269]	train-merror:0.28256	test-merror:0.38868	train-POINTS:32265.00000	test-POINTS:7100.00000
# [1270]	train-merror:0.28252	test-merror:0.38850	train-POINTS:32266.00000	test-POINTS:7101.00000
# [1271]	train-merror:0.28261	test-merror:0.38832	train-POINTS:32262.00000	test-POINTS:7103.00000
# [1272]	train-merror:0.28247	test-merror:0.38868	train-POINTS:32266.00000	test-POINTS:7099.00000
# [1273]	train-merror:0.28229	test-merror:0.38887	train-POINTS:32274.00000	test-POINTS:7098.00000
# [1274]	train-merror:0.28229	test-merror:0.38832	train-POINTS:32273.00000	test-POINTS:7102.00000
# [1275]	train-merror:0.28242	test-merror:0.38868	train-POINTS:32266.00000	test-POINTS:7099.00000
# [1276]	train-merror:0.28206	test-merror:0.38832	train-POINTS:32279.00000	test-POINTS:7101.00000
# [1277]	train-merror:0.28215	test-merror:0.38832	train-POINTS:32276.00000	test-POINTS:7104.00000
# [1278]	train-merror:0.28206	test-merror:0.38813	train-POINTS:32279.00000	test-POINTS:7104.00000
# [1279]	train-merror:0.28206	test-merror:0.38813	train-POINTS:32282.00000	test-POINTS:7103.00000
# [1280]	train-merror:0.28206	test-merror:0.38813	train-POINTS:32282.00000	test-POINTS:7102.00000
# [1281]	train-merror:0.28173	test-merror:0.38832	train-POINTS:32293.00000	test-POINTS:7101.00000
# [1282]	train-merror:0.28173	test-merror:0.38795	train-POINTS:32294.00000	test-POINTS:7107.00000
# [1283]	train-merror:0.28182	test-merror:0.38758	train-POINTS:32289.00000	test-POINTS:7111.00000
# [1284]	train-merror:0.28178	test-merror:0.38813	train-POINTS:32291.00000	test-POINTS:7107.00000
# [1285]	train-merror:0.28164	test-merror:0.38832	train-POINTS:32298.00000	test-POINTS:7105.00000
# [1286]	train-merror:0.28159	test-merror:0.38832	train-POINTS:32298.00000	test-POINTS:7104.00000
# [1287]	train-merror:0.28146	test-merror:0.38795	train-POINTS:32305.00000	test-POINTS:7106.00000
# [1288]	train-merror:0.28169	test-merror:0.38813	train-POINTS:32296.00000	test-POINTS:7103.00000
# [1289]	train-merror:0.28169	test-merror:0.38795	train-POINTS:32297.00000	test-POINTS:7106.00000
# [1290]	train-merror:0.28164	test-merror:0.38832	train-POINTS:32300.00000	test-POINTS:7102.00000
# [1291]	train-merror:0.28136	test-merror:0.38868	train-POINTS:32311.00000	test-POINTS:7098.00000
# [1292]	train-merror:0.28109	test-merror:0.38868	train-POINTS:32321.00000	test-POINTS:7096.00000
# [1293]	train-merror:0.28109	test-merror:0.38905	train-POINTS:32320.00000	test-POINTS:7094.00000
# [1294]	train-merror:0.28104	test-merror:0.38887	train-POINTS:32320.00000	test-POINTS:7097.00000
# [1295]	train-merror:0.28104	test-merror:0.38887	train-POINTS:32320.00000	test-POINTS:7097.00000
# [1296]	train-merror:0.28086	test-merror:0.38887	train-POINTS:32328.00000	test-POINTS:7097.00000
# [1297]	train-merror:0.28104	test-merror:0.38868	train-POINTS:32321.00000	test-POINTS:7098.00000
# [1298]	train-merror:0.28086	test-merror:0.38850	train-POINTS:32329.00000	test-POINTS:7100.00000
# [1299]	train-merror:0.28086	test-merror:0.38850	train-POINTS:32327.00000	test-POINTS:7102.00000
# [1300]	train-merror:0.28076	test-merror:0.38868	train-POINTS:32330.00000	test-POINTS:7101.00000
# [1301]	train-merror:0.28072	test-merror:0.38850	train-POINTS:32333.00000	test-POINTS:7101.00000
# [1302]	train-merror:0.28086	test-merror:0.38850	train-POINTS:32327.00000	test-POINTS:7101.00000
# [1303]	train-merror:0.28081	test-merror:0.38850	train-POINTS:32329.00000	test-POINTS:7100.00000
# [1304]	train-merror:0.28076	test-merror:0.38832	train-POINTS:32331.00000	test-POINTS:7101.00000
# [1305]	train-merror:0.28049	test-merror:0.38813	train-POINTS:32343.00000	test-POINTS:7102.00000
# [1306]	train-merror:0.28044	test-merror:0.38795	train-POINTS:32346.00000	test-POINTS:7103.00000
# [1307]	train-merror:0.28044	test-merror:0.38813	train-POINTS:32345.00000	test-POINTS:7103.00000
# [1308]	train-merror:0.28017	test-merror:0.38832	train-POINTS:32355.00000	test-POINTS:7101.00000
# [1309]	train-merror:0.28017	test-merror:0.38868	train-POINTS:32357.00000	test-POINTS:7098.00000
# [1310]	train-merror:0.27994	test-merror:0.38868	train-POINTS:32365.00000	test-POINTS:7098.00000
# [1311]	train-merror:0.27984	test-merror:0.38868	train-POINTS:32370.00000	test-POINTS:7098.00000
# [1312]	train-merror:0.27998	test-merror:0.38887	train-POINTS:32364.00000	test-POINTS:7096.00000
# [1313]	train-merror:0.27970	test-merror:0.38868	train-POINTS:32375.00000	test-POINTS:7097.00000
# [1314]	train-merror:0.27984	test-merror:0.38887	train-POINTS:32371.00000	test-POINTS:7096.00000
# [1315]	train-merror:0.27998	test-merror:0.38887	train-POINTS:32365.00000	test-POINTS:7097.00000
# [1316]	train-merror:0.27998	test-merror:0.38868	train-POINTS:32361.00000	test-POINTS:7099.00000
# [1317]	train-merror:0.28007	test-merror:0.38832	train-POINTS:32359.00000	test-POINTS:7102.00000
# [1318]	train-merror:0.28007	test-merror:0.38832	train-POINTS:32358.00000	test-POINTS:7102.00000
# [1319]	train-merror:0.27998	test-merror:0.38850	train-POINTS:32362.00000	test-POINTS:7100.00000
# [1320]	train-merror:0.27994	test-merror:0.38850	train-POINTS:32364.00000	test-POINTS:7099.00000
# [1321]	train-merror:0.27994	test-merror:0.38868	train-POINTS:32365.00000	test-POINTS:7098.00000
# [1322]	train-merror:0.27970	test-merror:0.38850	train-POINTS:32373.00000	test-POINTS:7099.00000
# [1323]	train-merror:0.27947	test-merror:0.38887	train-POINTS:32379.00000	test-POINTS:7094.00000
# [1324]	train-merror:0.27943	test-merror:0.38905	train-POINTS:32381.00000	test-POINTS:7094.00000
# [1325]	train-merror:0.27943	test-merror:0.38832	train-POINTS:32382.00000	test-POINTS:7102.00000
# [1326]	train-merror:0.27938	test-merror:0.38868	train-POINTS:32381.00000	test-POINTS:7099.00000
# [1327]	train-merror:0.27929	test-merror:0.38887	train-POINTS:32387.00000	test-POINTS:7097.00000
# [1328]	train-merror:0.27934	test-merror:0.38887	train-POINTS:32385.00000	test-POINTS:7097.00000
# [1329]	train-merror:0.27892	test-merror:0.38850	train-POINTS:32402.00000	test-POINTS:7100.00000
# [1330]	train-merror:0.27888	test-merror:0.38868	train-POINTS:32401.00000	test-POINTS:7098.00000
# [1331]	train-merror:0.27869	test-merror:0.38813	train-POINTS:32408.00000	test-POINTS:7104.00000
# [1332]	train-merror:0.27883	test-merror:0.38832	train-POINTS:32405.00000	test-POINTS:7103.00000
# [1333]	train-merror:0.27878	test-merror:0.38850	train-POINTS:32406.00000	test-POINTS:7100.00000
# [1334]	train-merror:0.27869	test-merror:0.38832	train-POINTS:32410.00000	test-POINTS:7102.00000
# [1335]	train-merror:0.27842	test-merror:0.38832	train-POINTS:32422.00000	test-POINTS:7103.00000
# [1336]	train-merror:0.27837	test-merror:0.38813	train-POINTS:32422.00000	test-POINTS:7103.00000
# [1337]	train-merror:0.27828	test-merror:0.38813	train-POINTS:32425.00000	test-POINTS:7103.00000
# [1338]	train-merror:0.27832	test-merror:0.38795	train-POINTS:32422.00000	test-POINTS:7105.00000
# [1339]	train-merror:0.27805	test-merror:0.38758	train-POINTS:32431.00000	test-POINTS:7109.00000
# [1340]	train-merror:0.27800	test-merror:0.38758	train-POINTS:32434.00000	test-POINTS:7108.00000
# [1341]	train-merror:0.27800	test-merror:0.38832	train-POINTS:32436.00000	test-POINTS:7100.00000
# [1342]	train-merror:0.27800	test-merror:0.38850	train-POINTS:32437.00000	test-POINTS:7098.00000
# [1343]	train-merror:0.27791	test-merror:0.38776	train-POINTS:32438.00000	test-POINTS:7106.00000
# [1344]	train-merror:0.27768	test-merror:0.38813	train-POINTS:32449.00000	test-POINTS:7102.00000
# [1345]	train-merror:0.27777	test-merror:0.38776	train-POINTS:32447.00000	test-POINTS:7106.00000
# [1346]	train-merror:0.27763	test-merror:0.38758	train-POINTS:32453.00000	test-POINTS:7108.00000
# [1347]	train-merror:0.27768	test-merror:0.38776	train-POINTS:32451.00000	test-POINTS:7107.00000
# [1348]	train-merror:0.27749	test-merror:0.38776	train-POINTS:32457.00000	test-POINTS:7107.00000
# [1349]	train-merror:0.27740	test-merror:0.38776	train-POINTS:32459.00000	test-POINTS:7106.00000
# [1350]	train-merror:0.27745	test-merror:0.38758	train-POINTS:32455.00000	test-POINTS:7108.00000
# [1351]	train-merror:0.27763	test-merror:0.38739	train-POINTS:32448.00000	test-POINTS:7111.00000
# [1352]	train-merror:0.27754	test-merror:0.38813	train-POINTS:32452.00000	test-POINTS:7104.00000
# [1353]	train-merror:0.27722	test-merror:0.38813	train-POINTS:32467.00000	test-POINTS:7104.00000
# [1354]	train-merror:0.27726	test-merror:0.38795	train-POINTS:32464.00000	test-POINTS:7106.00000
# [1355]	train-merror:0.27754	test-merror:0.38832	train-POINTS:32449.00000	test-POINTS:7103.00000
# [1356]	train-merror:0.27754	test-merror:0.38813	train-POINTS:32449.00000	test-POINTS:7105.00000
# [1357]	train-merror:0.27717	test-merror:0.38832	train-POINTS:32464.00000	test-POINTS:7103.00000
# [1358]	train-merror:0.27722	test-merror:0.38868	train-POINTS:32462.00000	test-POINTS:7099.00000
# [1359]	train-merror:0.27699	test-merror:0.38850	train-POINTS:32470.00000	test-POINTS:7101.00000
# [1360]	train-merror:0.27708	test-merror:0.38832	train-POINTS:32467.00000	test-POINTS:7104.00000
# [1361]	train-merror:0.27713	test-merror:0.38868	train-POINTS:32466.00000	test-POINTS:7100.00000
# [1362]	train-merror:0.27708	test-merror:0.38905	train-POINTS:32467.00000	test-POINTS:7097.00000
# [1363]	train-merror:0.27699	test-merror:0.38868	train-POINTS:32470.00000	test-POINTS:7099.00000
# [1364]	train-merror:0.27694	test-merror:0.38924	train-POINTS:32473.00000	test-POINTS:7093.00000
# [1365]	train-merror:0.27690	test-merror:0.38887	train-POINTS:32472.00000	test-POINTS:7097.00000
# [1366]	train-merror:0.27671	test-merror:0.38942	train-POINTS:32479.00000	test-POINTS:7091.00000
# [1367]	train-merror:0.27680	test-merror:0.38924	train-POINTS:32477.00000	test-POINTS:7092.00000
# [1368]	train-merror:0.27680	test-merror:0.38813	train-POINTS:32477.00000	test-POINTS:7104.00000
# [1369]	train-merror:0.27676	test-merror:0.38868	train-POINTS:32480.00000	test-POINTS:7098.00000
# [1370]	train-merror:0.27671	test-merror:0.38850	train-POINTS:32483.00000	test-POINTS:7100.00000
# [1371]	train-merror:0.27662	test-merror:0.38868	train-POINTS:32486.00000	test-POINTS:7098.00000
# [1372]	train-merror:0.27662	test-merror:0.38887	train-POINTS:32486.00000	test-POINTS:7097.00000
# [1373]	train-merror:0.27666	test-merror:0.38887	train-POINTS:32482.00000	test-POINTS:7097.00000
# [1374]	train-merror:0.27671	test-merror:0.38887	train-POINTS:32481.00000	test-POINTS:7097.00000
# [1375]	train-merror:0.27643	test-merror:0.38887	train-POINTS:32492.00000	test-POINTS:7097.00000
# [1376]	train-merror:0.27634	test-merror:0.38887	train-POINTS:32496.00000	test-POINTS:7097.00000
# [1377]	train-merror:0.27625	test-merror:0.38868	train-POINTS:32500.00000	test-POINTS:7097.00000
# [1378]	train-merror:0.27597	test-merror:0.38887	train-POINTS:32506.00000	test-POINTS:7097.00000
# [1379]	train-merror:0.27597	test-merror:0.38868	train-POINTS:32509.00000	test-POINTS:7099.00000
# [1380]	train-merror:0.27588	test-merror:0.38868	train-POINTS:32511.00000	test-POINTS:7097.00000
# [1381]	train-merror:0.27570	test-merror:0.38868	train-POINTS:32517.00000	test-POINTS:7098.00000
# [1382]	train-merror:0.27574	test-merror:0.38868	train-POINTS:32516.00000	test-POINTS:7098.00000
# [1383]	train-merror:0.27556	test-merror:0.38832	train-POINTS:32523.00000	test-POINTS:7100.00000
# [1384]	train-merror:0.27560	test-merror:0.38832	train-POINTS:32521.00000	test-POINTS:7103.00000
# [1385]	train-merror:0.27570	test-merror:0.38776	train-POINTS:32520.00000	test-POINTS:7107.00000
# [1386]	train-merror:0.27570	test-merror:0.38795	train-POINTS:32519.00000	test-POINTS:7104.00000
# [1387]	train-merror:0.27542	test-merror:0.38868	train-POINTS:32532.00000	test-POINTS:7099.00000
# [1388]	train-merror:0.27519	test-merror:0.38832	train-POINTS:32542.00000	test-POINTS:7102.00000
# [1389]	train-merror:0.27547	test-merror:0.38832	train-POINTS:32530.00000	test-POINTS:7103.00000
# [1390]	train-merror:0.27542	test-merror:0.38850	train-POINTS:32529.00000	test-POINTS:7103.00000
# [1391]	train-merror:0.27528	test-merror:0.38813	train-POINTS:32535.00000	test-POINTS:7107.00000
# [1392]	train-merror:0.27533	test-merror:0.38868	train-POINTS:32534.00000	test-POINTS:7102.00000
# [1393]	train-merror:0.27514	test-merror:0.38905	train-POINTS:32542.00000	test-POINTS:7098.00000
# [1394]	train-merror:0.27533	test-merror:0.38887	train-POINTS:32532.00000	test-POINTS:7099.00000
# [1395]	train-merror:0.27510	test-merror:0.38887	train-POINTS:32545.00000	test-POINTS:7099.00000
# [1396]	train-merror:0.27496	test-merror:0.38868	train-POINTS:32548.00000	test-POINTS:7101.00000
# [1397]	train-merror:0.27473	test-merror:0.38905	train-POINTS:32561.00000	test-POINTS:7098.00000
# [1398]	train-merror:0.27450	test-merror:0.38905	train-POINTS:32568.00000	test-POINTS:7099.00000
# [1399]	train-merror:0.27441	test-merror:0.38887	train-POINTS:32572.00000	test-POINTS:7101.00000

# %%
pred = bst.predict( xg_test )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-69-c60dbc046c71> in <module>
# ----> 1 pred = bst.predict( xg_test )
#
# NameError: name 'xg_test' is not defined
